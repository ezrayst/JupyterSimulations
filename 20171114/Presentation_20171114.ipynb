# %% [markdown]
# # MPM Verification

# %%
# Import Matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
# Import Data
plaxis_psi0 = np.genfromtxt("PLAXIS_psi0.csv", delimiter=",")
plaxis_psi_neg5 = np.genfromtxt("PLAXIS_psi-5.csv", delimiter=",")
plaxis_psi_pos5 = np.genfromtxt("PLAXIS_psi+5.csv", delimiter=",")

# %%
# Plot PLAXIS Results
plt.figure(figsize=(16,8))

plt.subplot(121)
plt.plot(plaxis_psi0[:,0] * -100, plaxis_psi0[:,1] * 1000, 'b', label='$\Psi = 0$')
plt.plot(plaxis_psi_neg5[:,0] * -100, plaxis_psi_neg5[:,1] * 1000, 'r', label='$\Psi = -5$')
plt.plot(plaxis_psi_pos5[:,0] * -100, plaxis_psi_pos5[:,1] * 1000, 'g', label='$\Psi = +5$')
plt.axis([0, 0.2, 0, 4000])
plt.legend(loc='lower right')
plt.title('PLAXIS')
plt.xlabel('Axial Strain [%]')
plt.ylabel('Axial Stress (Pa)')
plt.grid(True)

plt.subplot(122)
plt.plot(plaxis_psi0[:,0] * -100, plaxis_psi0[:,2] * -100, 'b', label='$\Psi = 0$')
plt.plot(plaxis_psi_neg5[:,0] * -100, plaxis_psi_neg5[:,2] * -100, 'r', label='$\Psi = -5$')
plt.plot(plaxis_psi_pos5[:,0] * -100, plaxis_psi_pos5[:,2] * -100, 'g', label='$\Psi = +5$')
plt.axis([0, 0.2, -0.02, 0.06])
plt.legend(loc='upper left')
plt.title('PLAXIS')
plt.xlabel('Axial Strain [%]')
plt.ylabel('Volumetric Strain [%]')
plt.grid(True)    
    
plt.show()

# %% [markdown]
# ## Plotting all 4 points in Element
#
# - Point 0: botom left
# - Point 1: bottom right
# - Point 2: upper left
# - Point 3: upper right

# %% [markdown]
# # 1 Linear Elastic without Iteration
# ## Velocity on top and bottom

# %%
# Getting more data

stress_original_ile_0 = np.genfromtxt("test_b1/stress_0.txt")
stress_original_ile_1 = np.genfromtxt("test_b1/stress_1.txt")
stress_original_ile_2 = np.genfromtxt("test_b1/stress_2.txt")
stress_original_ile_3 = np.genfromtxt("test_b1/stress_3.txt")

strain_original_ile_0 = np.genfromtxt("test_b1/strain_0.txt")
strain_original_ile_1 = np.genfromtxt("test_b1/strain_1.txt")
strain_original_ile_2 = np.genfromtxt("test_b1/strain_2.txt")
strain_original_ile_3 = np.genfromtxt("test_b1/strain_3.txt")

acceleration_original_ile_0 = np.genfromtxt("test_b1/acceleration_0.txt")
acceleration_original_ile_1 = np.genfromtxt("test_b1/acceleration_1.txt")
acceleration_original_ile_2 = np.genfromtxt("test_b1/acceleration_2.txt")
acceleration_original_ile_3 = np.genfromtxt("test_b1/acceleration_3.txt")

velocity_original_ile_0 = np.genfromtxt("test_b1/velocity_0.txt")
velocity_original_ile_1 = np.genfromtxt("test_b1/velocity_1.txt")
velocity_original_ile_2 = np.genfromtxt("test_b1/velocity_2.txt")
velocity_original_ile_3 = np.genfromtxt("test_b1/velocity_3.txt")

# %%
# Plot Comparison

plt.figure(figsize=(16,48))

plt.subplot(811)
plt.plot(strain_original_ile_0[:,0], strain_original_ile_0[:,1] * 100, 'y', label='Point 0')
plt.plot(strain_original_ile_1[:,0], strain_original_ile_1[:,1] * 100, 'r--', label='Point 1')
plt.plot(strain_original_ile_2[:,0], strain_original_ile_2[:,1] * 100, 'b--', label='Point 2')
plt.plot(strain_original_ile_3[:,0], strain_original_ile_3[:,1] * 100, 'g', label='Point 3')
plt.axis([0, 100000, 0, 0.005])
plt.legend(loc='lower right')
plt.title('Strain - X')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Strain [%]')
plt.grid(True)

plt.subplot(812)
plt.plot(strain_original_ile_0[:,0], strain_original_ile_0[:,2] * 100, 'y', label='Point 0')
plt.plot(strain_original_ile_1[:,0], strain_original_ile_1[:,2] * 100, 'r--', label='Point 1')
plt.plot(strain_original_ile_2[:,0], strain_original_ile_2[:,2] * 100, 'b--', label='Point 2')
plt.plot(strain_original_ile_3[:,0], strain_original_ile_3[:,2] * 100, 'g', label='Point 3')
plt.axis([0, 100000, -0.5, 0 ])
plt.legend(loc='upper right')
plt.title('Strain - Y')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Strain [%]')
plt.grid(True)

plt.subplot(813)
plt.plot(stress_original_ile_0[:,0], stress_original_ile_0[:,1], 'y', label='Point 0')
plt.plot(stress_original_ile_1[:,0], stress_original_ile_1[:,1], 'r--', label='Point 1')
plt.plot(stress_original_ile_2[:,0], stress_original_ile_2[:,1], 'b--', label='Point 2')
plt.plot(stress_original_ile_3[:,0], stress_original_ile_3[:,1], 'g', label='Point 3')
plt.axis([0, 100000, -12000, 0])
plt.legend(loc='upper right')
plt.title('Stress - X')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Stress [Pa]')
plt.grid(True)

plt.subplot(814)
plt.plot(stress_original_ile_0[:,0], stress_original_ile_0[:,2], 'y', label='Point 0')
plt.plot(stress_original_ile_1[:,0], stress_original_ile_1[:,2], 'r--', label='Point 1')
plt.plot(stress_original_ile_2[:,0], stress_original_ile_2[:,2], 'b--', label='Point 2')
plt.plot(stress_original_ile_3[:,0], stress_original_ile_3[:,2], 'g', label='Point 3')
plt.axis([0, 100000, -45000, 0])
plt.legend(loc='upper right')
plt.title('Stress - Y')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Stress [Pa]')
plt.grid(True)

plt.subplot(815)
plt.plot(acceleration_original_ile_0[:,0], acceleration_original_ile_0[:,1], 'y', label='Point 0')
plt.plot(acceleration_original_ile_1[:,0], acceleration_original_ile_1[:,1], 'r--', label='Point 1')
plt.plot(acceleration_original_ile_2[:,0], acceleration_original_ile_2[:,1], 'b--', label='Point 2')
plt.plot(acceleration_original_ile_3[:,0], acceleration_original_ile_3[:,1], 'g', label='Point 3')
plt.axis([0, 100000, 0, 10])
plt.legend(loc='upper right')
plt.title('Acceleration - X')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Acceleration [m / s^2]')
plt.grid(True)

plt.subplot(816)
plt.plot(acceleration_original_ile_0[:,0], acceleration_original_ile_0[:,2], 'y', label='Point 0')
plt.plot(acceleration_original_ile_1[:,0], acceleration_original_ile_1[:,2], 'r--', label='Point 1')
plt.plot(acceleration_original_ile_2[:,0], acceleration_original_ile_2[:,2], 'b--', label='Point 2')
plt.plot(acceleration_original_ile_3[:,0], acceleration_original_ile_3[:,2], 'g', label='Point 3')
plt.axis([0, 100000, -0.001, 0.001])
plt.legend(loc='upper right')
plt.title('Acceleration - Y')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Acceleration [m / s^2]')
plt.grid(True)

plt.subplot(817)
plt.plot(velocity_original_ile_0[:,0], velocity_original_ile_0[:,1], 'y', label='Point 0')
plt.plot(velocity_original_ile_1[:,0], velocity_original_ile_1[:,1], 'r--', label='Point 1')
plt.plot(velocity_original_ile_2[:,0], velocity_original_ile_2[:,1], 'b--', label='Point 2')
plt.plot(velocity_original_ile_3[:,0], velocity_original_ile_3[:,1], 'g', label='Point 3')
plt.axis([0, 100000, 0, 0.0001])
plt.legend(loc='upper left')
plt.title('Velocity - X')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Velocity [m / s]')
plt.grid(True)

plt.subplot(818)
plt.plot(velocity_original_ile_0[:,0], velocity_original_ile_0[:,2], 'y', label='Point 0')
plt.plot(velocity_original_ile_1[:,0], velocity_original_ile_1[:,2], 'r--', label='Point 1')
plt.plot(velocity_original_ile_2[:,0], velocity_original_ile_2[:,2], 'b--', label='Point 2')
plt.plot(velocity_original_ile_3[:,0], velocity_original_ile_3[:,2], 'g', label='Point 3')
plt.axis([0, 100000, -0.002, 0])
plt.legend(loc='lower right')
plt.title('Velocity - Y')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Velocity [m / s]')
plt.grid(True)

plt.show()

# %% [markdown]
# # 2 Linear Elastic without Iteration
# ## Velocity on top only

# %%
# Getting more data

stress_original_iles_0 = np.genfromtxt("test_c1/stress_0.txt")
stress_original_iles_1 = np.genfromtxt("test_c1/stress_1.txt")
stress_original_iles_2 = np.genfromtxt("test_c1/stress_2.txt")
stress_original_iles_3 = np.genfromtxt("test_c1/stress_3.txt")

strain_original_iles_0 = np.genfromtxt("test_c1/strain_0.txt")
strain_original_iles_1 = np.genfromtxt("test_c1/strain_1.txt")
strain_original_iles_2 = np.genfromtxt("test_c1/strain_2.txt")
strain_original_iles_3 = np.genfromtxt("test_c1/strain_3.txt")

acceleration_original_iles_0 = np.genfromtxt("test_c1/acceleration_0.txt")
acceleration_original_iles_1 = np.genfromtxt("test_c1/acceleration_1.txt")
acceleration_original_iles_2 = np.genfromtxt("test_c1/acceleration_2.txt")
acceleration_original_iles_3 = np.genfromtxt("test_c1/acceleration_3.txt")

velocity_original_iles_0 = np.genfromtxt("test_c1/velocity_0.txt")
velocity_original_iles_1 = np.genfromtxt("test_c1/velocity_1.txt")
velocity_original_iles_2 = np.genfromtxt("test_c1/velocity_2.txt")
velocity_original_iles_3 = np.genfromtxt("test_c1/velocity_3.txt")

# %%
# Plot Comparison

plt.figure(figsize=(16,48))

plt.subplot(811)
plt.plot(strain_original_iles_0[:,0], strain_original_iles_0[:,1] * 100, 'y', label='Point 0')
plt.plot(strain_original_iles_1[:,0], strain_original_iles_1[:,1] * 100, 'r--', label='Point 1')
plt.plot(strain_original_iles_2[:,0], strain_original_iles_2[:,1] * 100, 'b--', label='Point 2')
plt.plot(strain_original_iles_3[:,0], strain_original_iles_3[:,1] * 100, 'g', label='Point 3')
plt.axis([0, 100000, 0, 0.01])
plt.legend(loc='lower right')
plt.title('Strain - X')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Strain [%]')
plt.grid(True)

plt.subplot(812)
plt.plot(strain_original_iles_0[:,0], strain_original_iles_0[:,2] * 100, 'y', label='Point 0')
plt.plot(strain_original_iles_1[:,0], strain_original_iles_1[:,2] * 100, 'r--', label='Point 1')
plt.plot(strain_original_iles_2[:,0], strain_original_iles_2[:,2] * 100, 'b--', label='Point 2')
plt.plot(strain_original_iles_3[:,0], strain_original_iles_3[:,2] * 100, 'g', label='Point 3')
plt.axis([0, 100000, -0.3, 0 ])
plt.legend(loc='upper right')
plt.title('Strain - Y')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Strain [%]')
plt.grid(True)

plt.subplot(813)
plt.plot(stress_original_iles_0[:,0], stress_original_iles_0[:,1], 'y', label='Point 0')
plt.plot(stress_original_iles_1[:,0], stress_original_iles_1[:,1], 'r--', label='Point 1')
plt.plot(stress_original_iles_2[:,0], stress_original_iles_2[:,1], 'b--', label='Point 2')
plt.plot(stress_original_iles_3[:,0], stress_original_iles_3[:,1], 'g', label='Point 3')
plt.axis([0, 100000, -8000, 0])
plt.legend(loc='lower right')
plt.title('Stress - X')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Stress [Pa]')
plt.grid(True)

plt.subplot(814)
plt.plot(stress_original_iles_0[:,0], stress_original_iles_0[:,2], 'y', label='Point 0')
plt.plot(stress_original_iles_1[:,0], stress_original_iles_1[:,2], 'r--', label='Point 1')
plt.plot(stress_original_iles_2[:,0], stress_original_iles_2[:,2], 'b--', label='Point 2')
plt.plot(stress_original_iles_3[:,0], stress_original_iles_3[:,2], 'g', label='Point 3')
plt.axis([0, 100000, -25000, 0])
plt.legend(loc='upper right')
plt.title('Stress - Y')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Stress [Pa]')
plt.grid(True)

plt.subplot(815)
plt.plot(acceleration_original_iles_0[:,0], acceleration_original_iles_0[:,1], 'y', label='Point 0')
plt.plot(acceleration_original_iles_1[:,0], acceleration_original_iles_1[:,1], 'r--', label='Point 1')
plt.plot(acceleration_original_iles_2[:,0], acceleration_original_iles_2[:,1], 'b--', label='Point 2')
plt.plot(acceleration_original_iles_3[:,0], acceleration_original_iles_3[:,1], 'g', label='Point 3')
plt.axis([0, 100000, 0, 10])
plt.legend(loc='upper right')
plt.title('Acceleration - X')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Acceleration [m / s^2]')
plt.grid(True)

plt.subplot(816)
plt.plot(acceleration_original_iles_0[:,0], acceleration_original_iles_0[:,2], 'y', label='Point 0')
plt.plot(acceleration_original_iles_1[:,0], acceleration_original_iles_1[:,2], 'r--', label='Point 1')
plt.plot(acceleration_original_iles_2[:,0], acceleration_original_iles_2[:,2], 'b--', label='Point 2')
plt.plot(acceleration_original_iles_3[:,0], acceleration_original_iles_3[:,2], 'g', label='Point 3')
plt.axis([0, 100000, -0.001, 0.001])
plt.legend(loc='lower right')
plt.title('Acceleration - Y')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Acceleration [m / s^2]')
plt.grid(True)

plt.subplot(817)
plt.plot(velocity_original_iles_0[:,0], velocity_original_iles_0[:,1], 'y', label='Point 0')
plt.plot(velocity_original_iles_1[:,0], velocity_original_iles_1[:,1], 'r--', label='Point 1')
plt.plot(velocity_original_iles_2[:,0], velocity_original_iles_2[:,1], 'b--', label='Point 2')
plt.plot(velocity_original_iles_3[:,0], velocity_original_iles_3[:,1], 'g', label='Point 3')
plt.axis([0, 100000, 0, 0.0002])
plt.legend(loc='upper left')
plt.title('Velocity - X')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Velocity [m / s]')
plt.grid(True)

plt.subplot(818)
plt.plot(velocity_original_iles_0[:,0], velocity_original_iles_0[:,2], 'y', label='Point 0')
plt.plot(velocity_original_iles_1[:,0], velocity_original_iles_1[:,2], 'r--', label='Point 1')
plt.plot(velocity_original_iles_2[:,0], velocity_original_iles_2[:,2], 'b--', label='Point 2')
plt.plot(velocity_original_iles_3[:,0], velocity_original_iles_3[:,2], 'g', label='Point 3')
plt.axis([0, 100000, -0.002, 0])
plt.legend(loc='lower right')
plt.title('Velocity - Y')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Velocity [m / s]')
plt.grid(True)

plt.show()

# %% [markdown]
# # 3 Mohr Coulomb without Iteration
# ## Velocity on top only

# %%
# Getting more data

stress_original_mc_0 = np.genfromtxt("test_d1/stress_0.txt")
stress_original_mc_1 = np.genfromtxt("test_d1/stress_1.txt")
stress_original_mc_2 = np.genfromtxt("test_d1/stress_2.txt")
stress_original_mc_3 = np.genfromtxt("test_d1/stress_3.txt")

strain_original_mc_0 = np.genfromtxt("test_d1/strain_0.txt")
strain_original_mc_1 = np.genfromtxt("test_d1/strain_1.txt")
strain_original_mc_2 = np.genfromtxt("test_d1/strain_2.txt")
strain_original_mc_3 = np.genfromtxt("test_d1/strain_3.txt")

acceleration_original_mc_0 = np.genfromtxt("test_d1/acceleration_0.txt")
acceleration_original_mc_1 = np.genfromtxt("test_d1/acceleration_1.txt")
acceleration_original_mc_2 = np.genfromtxt("test_d1/acceleration_2.txt")
acceleration_original_mc_3 = np.genfromtxt("test_d1/acceleration_3.txt")

velocity_original_mc_0 = np.genfromtxt("test_d1/velocity_0.txt")
velocity_original_mc_1 = np.genfromtxt("test_d1/velocity_1.txt")
velocity_original_mc_2 = np.genfromtxt("test_d1/velocity_2.txt")
velocity_original_mc_3 = np.genfromtxt("test_d1/velocity_3.txt")

# %%
# Plot Comparison

plt.figure(figsize=(16,48))

plt.subplot(811)
plt.plot(strain_original_mc_0[:,0], strain_original_mc_0[:,1] * 100, 'y', label='Point 0')
plt.plot(strain_original_mc_1[:,0], strain_original_mc_1[:,1] * 100, 'r--', label='Point 1')
plt.plot(strain_original_mc_2[:,0], strain_original_mc_2[:,1] * 100, 'b--', label='Point 2')
plt.plot(strain_original_mc_3[:,0], strain_original_mc_3[:,1] * 100, 'g', label='Point 3')
plt.axis([0, 100000, 0, 0.01])
plt.legend(loc='lower right')
plt.title('Strain - X')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Strain [%]')
plt.grid(True)

plt.subplot(812)
plt.plot(strain_original_mc_0[:,0], strain_original_mc_0[:,2] * 100, 'y', label='Point 0')
plt.plot(strain_original_mc_1[:,0], strain_original_mc_1[:,2] * 100, 'r--', label='Point 1')
plt.plot(strain_original_mc_2[:,0], strain_original_mc_2[:,2] * 100, 'b--', label='Point 2')
plt.plot(strain_original_mc_3[:,0], strain_original_mc_3[:,2] * 100, 'g', label='Point 3')
plt.axis([0, 100000, -0.3, 0 ])
plt.legend(loc='upper right')
plt.title('Strain - Y')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Strain [%]')
plt.grid(True)

plt.subplot(813)
plt.plot(stress_original_mc_0[:,0], stress_original_mc_0[:,1], 'y', label='Point 0')
plt.plot(stress_original_mc_1[:,0], stress_original_mc_1[:,1], 'r--', label='Point 1')
plt.plot(stress_original_mc_2[:,0], stress_original_mc_2[:,1], 'b--', label='Point 2')
plt.plot(stress_original_mc_3[:,0], stress_original_mc_3[:,1], 'g', label='Point 3')
plt.axis([0, 100000, -8000, 0])
plt.legend(loc='lower right')
plt.title('Stress - X')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Stress [Pa]')
plt.grid(True)

plt.subplot(814)
plt.plot(stress_original_mc_0[:,0], stress_original_mc_0[:,2], 'y', label='Point 0')
plt.plot(stress_original_mc_1[:,0], stress_original_mc_1[:,2], 'r--', label='Point 1')
plt.plot(stress_original_mc_2[:,0], stress_original_mc_2[:,2], 'b--', label='Point 2')
plt.plot(stress_original_mc_3[:,0], stress_original_mc_3[:,2], 'g', label='Point 3')
plt.axis([0, 100000, -25000, 0])
plt.legend(loc='upper right')
plt.title('Stress - Y')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Stress [Pa]')
plt.grid(True)

plt.subplot(815)
plt.plot(acceleration_original_mc_0[:,0], acceleration_original_mc_0[:,1], 'y', label='Point 0')
plt.plot(acceleration_original_mc_1[:,0], acceleration_original_mc_1[:,1], 'r--', label='Point 1')
plt.plot(acceleration_original_mc_2[:,0], acceleration_original_mc_2[:,1], 'b--', label='Point 2')
plt.plot(acceleration_original_mc_3[:,0], acceleration_original_mc_3[:,1], 'g', label='Point 3')
plt.axis([0, 100000, 0, 10])
plt.legend(loc='upper right')
plt.title('Acceleration - X')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Acceleration [m / s^2]')
plt.grid(True)

plt.subplot(816)
plt.plot(acceleration_original_mc_0[:,0], acceleration_original_mc_0[:,2], 'y', label='Point 0')
plt.plot(acceleration_original_mc_1[:,0], acceleration_original_mc_1[:,2], 'r--', label='Point 1')
plt.plot(acceleration_original_mc_2[:,0], acceleration_original_mc_2[:,2], 'b--', label='Point 2')
plt.plot(acceleration_original_mc_3[:,0], acceleration_original_mc_3[:,2], 'g', label='Point 3')
plt.axis([0, 100000, -0.001, 0.001])
plt.legend(loc='lower right')
plt.title('Acceleration - Y')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Acceleration [m / s^2]')
plt.grid(True)

plt.subplot(817)
plt.plot(velocity_original_mc_0[:,0], velocity_original_mc_0[:,1], 'y', label='Point 0')
plt.plot(velocity_original_mc_1[:,0], velocity_original_mc_1[:,1], 'r--', label='Point 1')
plt.plot(velocity_original_mc_2[:,0], velocity_original_mc_2[:,1], 'b--', label='Point 2')
plt.plot(velocity_original_mc_3[:,0], velocity_original_mc_3[:,1], 'g', label='Point 3')
plt.axis([0, 100000, 0, 0.0002])
plt.legend(loc='upper left')
plt.title('Velocity - X')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Velocity [m / s]')
plt.grid(True)

plt.subplot(818)
plt.plot(velocity_original_mc_0[:,0], velocity_original_mc_0[:,2], 'y', label='Point 0')
plt.plot(velocity_original_mc_1[:,0], velocity_original_mc_1[:,2], 'r--', label='Point 1')
plt.plot(velocity_original_mc_2[:,0], velocity_original_mc_2[:,2], 'b--', label='Point 2')
plt.plot(velocity_original_mc_3[:,0], velocity_original_mc_3[:,2], 'g', label='Point 3')
plt.axis([0, 100000, -0.002, 0])
plt.legend(loc='lower right')
plt.title('Velocity - Y')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Velocity [m / s]')
plt.grid(True)

plt.show()

# %%
# Plot Comparison for Psi = 0, No Damping
plt.figure(figsize=(16,16))

plt.subplot(221)
plt.plot(plaxis_psi0[:,0] * -100, plaxis_psi0[:,1] * 1000, 'k', label='PLAXIS')
plt.plot(strain_original_mc_0[:,2] * -100 , stress_original_mc_0[:,2] * -1, 'y', label='Point 0')
plt.plot(strain_original_mc_1[:,2] * -100 , stress_original_mc_1[:,2] * -1, 'r--', label='Point 1')
plt.plot(strain_original_mc_2[:,2] * -100 , stress_original_mc_2[:,2] * -1, 'b--', label='Point 2')
plt.plot(strain_original_mc_3[:,2] * -100 , stress_original_mc_3[:,2] * -1, 'g', label='Point 3')
plt.axis([0, 0.2, 0, 5000])
plt.legend(loc='lower right')
plt.title('No Damping, Vertical Stress, $\Psi = 0$')
plt.xlabel('Axial Strain [%]')
plt.ylabel('Axial Stress (Pa)')
plt.grid(True)

plt.subplot(222)
plt.plot(plaxis_psi0[:,0] * -100, plaxis_psi0[:,2] * -100, 'k', label='PLAXIS')
plt.plot(strain_original_mc_0[:,2] * -100 , (strain_original_mc_0[:,2] + strain_original_mc_0[:,1]) * -100, 'y', label='Point 0')
plt.plot(strain_original_mc_1[:,2] * -100 , (strain_original_mc_1[:,2] + strain_original_mc_1[:,1]) * -100, 'r--', label='Point 1')
plt.plot(strain_original_mc_2[:,2] * -100 , (strain_original_mc_2[:,2] + strain_original_mc_2[:,1]) * -100, 'b--', label='Point 2')
plt.plot(strain_original_mc_3[:,2] * -100 , (strain_original_mc_3[:,2] + strain_original_mc_3[:,1]) * -100, 'g', label='Point 3')
plt.axis([0, 0.2, -0.02, 0.06])
plt.legend(loc='upper left')
plt.title('No Damping, $\Psi = 0$')
plt.xlabel('Axial Strain [%]')
plt.ylabel('Volumetric Strain [%]')
plt.grid(True)    

plt.subplot(223)
plt.plot(strain_original_mc_0[:,2] * -100 , stress_original_mc_0[:,1] * -1, 'y', label='Point 0')
plt.plot(strain_original_mc_1[:,2] * -100 , stress_original_mc_1[:,1] * -1, 'r--', label='Point 1')
plt.plot(strain_original_mc_2[:,2] * -100 , stress_original_mc_2[:,1] * -1, 'b--', label='Point 2')
plt.plot(strain_original_mc_3[:,2] * -100 , stress_original_mc_3[:,1] * -1, 'g', label='Point 3')
plt.axis([0, 0.2, 0, 300])
plt.legend(loc='upper right')
plt.title('No Damping, Horizontal Stress, $\Psi = 0$')
plt.xlabel('Axial Strain [%]')
plt.ylabel('Horizontal Stress (Pa)')
plt.grid(True)

plt.show()

# %% [markdown]
# # 4 Linear Elastic with Iteration
# ## Velocity on top and bottom

# %%
# Getting more data

stress_iteration_ile_0 = np.genfromtxt("test_b2/stress_0.txt")
stress_iteration_ile_1 = np.genfromtxt("test_b2/stress_1.txt")
stress_iteration_ile_2 = np.genfromtxt("test_b2/stress_2.txt")
stress_iteration_ile_3 = np.genfromtxt("test_b2/stress_3.txt")

strain_iteration_ile_0 = np.genfromtxt("test_b2/strain_0.txt")
strain_iteration_ile_1 = np.genfromtxt("test_b2/strain_1.txt")
strain_iteration_ile_2 = np.genfromtxt("test_b2/strain_2.txt")
strain_iteration_ile_3 = np.genfromtxt("test_b2/strain_3.txt")

acceleration_iteration_ile_0 = np.genfromtxt("test_b2/acceleration_0.txt")
acceleration_iteration_ile_1 = np.genfromtxt("test_b2/acceleration_1.txt")
acceleration_iteration_ile_2 = np.genfromtxt("test_b2/acceleration_2.txt")
acceleration_iteration_ile_3 = np.genfromtxt("test_b2/acceleration_3.txt")

velocity_iteration_ile_0 = np.genfromtxt("test_b2/velocity_0.txt")
velocity_iteration_ile_1 = np.genfromtxt("test_b2/velocity_1.txt")
velocity_iteration_ile_2 = np.genfromtxt("test_b2/velocity_2.txt")
velocity_iteration_ile_3 = np.genfromtxt("test_b2/velocity_3.txt")

# %%
# Plot Comparison

plt.figure(figsize=(16,48))

plt.subplot(811)
plt.plot(strain_iteration_ile_0[:,0], strain_iteration_ile_0[:,1] * 100, 'y', label='Point 0')
plt.plot(strain_iteration_ile_1[:,0], strain_iteration_ile_1[:,1] * 100, 'r--', label='Point 1')
plt.plot(strain_iteration_ile_2[:,0], strain_iteration_ile_2[:,1] * 100, 'b--', label='Point 2')
plt.plot(strain_iteration_ile_3[:,0], strain_iteration_ile_3[:,1] * 100, 'g', label='Point 3')
plt.axis([0, 100000, 0, 0.2])
plt.legend(loc='lower right')
plt.title('Strain - X')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Strain [%]')
plt.grid(True)

plt.subplot(812)
plt.plot(strain_iteration_ile_0[:,0], strain_iteration_ile_0[:,2] * 100, 'y', label='Point 0')
plt.plot(strain_iteration_ile_1[:,0], strain_iteration_ile_1[:,2] * 100, 'r--', label='Point 1')
plt.plot(strain_iteration_ile_2[:,0], strain_iteration_ile_2[:,2] * 100, 'b--', label='Point 2')
plt.plot(strain_iteration_ile_3[:,0], strain_iteration_ile_3[:,2] * 100, 'g', label='Point 3')
plt.axis([0, 100000, -0.8, 0 ])
plt.legend(loc='upper right')
plt.title('Strain - Y')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Strain [%]')
plt.grid(True)

plt.subplot(813)
plt.plot(stress_iteration_ile_0[:,0], stress_iteration_ile_0[:,1], 'y', label='Point 0')
plt.plot(stress_iteration_ile_1[:,0], stress_iteration_ile_1[:,1], 'r--', label='Point 1')
plt.plot(stress_iteration_ile_2[:,0], stress_iteration_ile_2[:,1], 'b--', label='Point 2')
plt.plot(stress_iteration_ile_3[:,0], stress_iteration_ile_3[:,1], 'g', label='Point 3')
plt.axis([0, 100000, -0.001, 0.001])
plt.legend(loc='lower right')
plt.title('Stress - X')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Stress [Pa]')
plt.grid(True)

plt.subplot(814)
plt.plot(stress_iteration_ile_0[:,0], stress_iteration_ile_0[:,2], 'y', label='Point 0')
plt.plot(stress_iteration_ile_1[:,0], stress_iteration_ile_1[:,2], 'r--', label='Point 1')
plt.plot(stress_iteration_ile_2[:,0], stress_iteration_ile_2[:,2], 'b--', label='Point 2')
plt.plot(stress_iteration_ile_3[:,0], stress_iteration_ile_3[:,2], 'g', label='Point 3')
plt.axis([0, 100000, -90000, 0])
plt.legend(loc='upper right')
plt.title('Stress - Y')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Stress [Pa]')
plt.grid(True)

plt.subplot(815)
plt.plot(acceleration_iteration_ile_0[:,0], acceleration_iteration_ile_0[:,1], 'y', label='Point 0')
plt.plot(acceleration_iteration_ile_1[:,0], acceleration_iteration_ile_1[:,1], 'r--', label='Point 1')
plt.plot(acceleration_iteration_ile_2[:,0], acceleration_iteration_ile_2[:,1], 'b--', label='Point 2')
plt.plot(acceleration_iteration_ile_3[:,0], acceleration_iteration_ile_3[:,1], 'g', label='Point 3')
plt.axis([0, 100000, -0.1, 0.1])
plt.legend(loc='upper right')
plt.title('Acceleration - X')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Acceleration [m / s^2]')
plt.grid(True)

plt.subplot(816)
plt.plot(acceleration_iteration_ile_0[:,0], acceleration_iteration_ile_0[:,2], 'y', label='Point 0')
plt.plot(acceleration_iteration_ile_1[:,0], acceleration_iteration_ile_1[:,2], 'r--', label='Point 1')
plt.plot(acceleration_iteration_ile_2[:,0], acceleration_iteration_ile_2[:,2], 'b--', label='Point 2')
plt.plot(acceleration_iteration_ile_3[:,0], acceleration_iteration_ile_3[:,2], 'g', label='Point 3')
plt.axis([0, 100000, -0.001, 0.001])
plt.legend(loc='lower right')
plt.title('Acceleration - Y')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Acceleration [m / s^2]')
plt.grid(True)

plt.subplot(817)
plt.plot(velocity_iteration_ile_0[:,0], velocity_iteration_ile_0[:,1], 'y', label='Point 0')
plt.plot(velocity_iteration_ile_1[:,0], velocity_iteration_ile_1[:,1], 'r--', label='Point 1')
plt.plot(velocity_iteration_ile_2[:,0], velocity_iteration_ile_2[:,1], 'b--', label='Point 2')
plt.plot(velocity_iteration_ile_3[:,0], velocity_iteration_ile_3[:,1], 'g', label='Point 3')
plt.axis([0, 100000, 0, 0.0005])
plt.legend(loc='lower right')
plt.title('Velocity - X')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Velocity [m / s]')
plt.grid(True)

plt.subplot(818)
plt.plot(velocity_iteration_ile_0[:,0], velocity_iteration_ile_0[:,2], 'y', label='Point 0')
plt.plot(velocity_iteration_ile_1[:,0], velocity_iteration_ile_1[:,2], 'r--', label='Point 1')
plt.plot(velocity_iteration_ile_2[:,0], velocity_iteration_ile_2[:,2], 'b--', label='Point 2')
plt.plot(velocity_iteration_ile_3[:,0], velocity_iteration_ile_3[:,2], 'g', label='Point 3')
plt.axis([0, 100000, -0.002, 0])
plt.legend(loc='lower right')
plt.title('Velocity - Y')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Velocity [m / s]')
plt.grid(True)

plt.show()

# %% [markdown]
# # 5 Linear Elastic with Iteration
# ## Velocity on top only

# %%
# Getting more data

stress_iteration_iles_0 = np.genfromtxt("test_c2/stress_0.txt")
stress_iteration_iles_1 = np.genfromtxt("test_c2/stress_1.txt")
stress_iteration_iles_2 = np.genfromtxt("test_c2/stress_2.txt")
stress_iteration_iles_3 = np.genfromtxt("test_c2/stress_3.txt")

strain_iteration_iles_0 = np.genfromtxt("test_c2/strain_0.txt")
strain_iteration_iles_1 = np.genfromtxt("test_c2/strain_1.txt")
strain_iteration_iles_2 = np.genfromtxt("test_c2/strain_2.txt")
strain_iteration_iles_3 = np.genfromtxt("test_c2/strain_3.txt")

acceleration_iteration_iles_0 = np.genfromtxt("test_c2/acceleration_0.txt")
acceleration_iteration_iles_1 = np.genfromtxt("test_c2/acceleration_1.txt")
acceleration_iteration_iles_2 = np.genfromtxt("test_c2/acceleration_2.txt")
acceleration_iteration_iles_3 = np.genfromtxt("test_c2/acceleration_3.txt")

velocity_iteration_iles_0 = np.genfromtxt("test_c2/velocity_0.txt")
velocity_iteration_iles_1 = np.genfromtxt("test_c2/velocity_1.txt")
velocity_iteration_iles_2 = np.genfromtxt("test_c2/velocity_2.txt")
velocity_iteration_iles_3 = np.genfromtxt("test_c2/velocity_3.txt")

# %%
# Plot Comparison

plt.figure(figsize=(16,48))

plt.subplot(811)
plt.plot(strain_iteration_iles_0[:,0], strain_iteration_iles_0[:,1] * 100, 'y', label='Point 0')
plt.plot(strain_iteration_iles_1[:,0], strain_iteration_iles_1[:,1] * 100, 'r--', label='Point 1')
plt.plot(strain_iteration_iles_2[:,0], strain_iteration_iles_2[:,1] * 100, 'b--', label='Point 2')
plt.plot(strain_iteration_iles_3[:,0], strain_iteration_iles_3[:,1] * 100, 'g', label='Point 3')
plt.axis([0, 100000, 0, 0.2])
plt.legend(loc='lower right')
plt.title('Strain - X')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Strain [%]')
plt.grid(True)

plt.subplot(812)
plt.plot(strain_iteration_iles_0[:,0], strain_iteration_iles_0[:,2] * 100, 'y', label='Point 0')
plt.plot(strain_iteration_iles_1[:,0], strain_iteration_iles_1[:,2] * 100, 'r--', label='Point 1')
plt.plot(strain_iteration_iles_2[:,0], strain_iteration_iles_2[:,2] * 100, 'b--', label='Point 2')
plt.plot(strain_iteration_iles_3[:,0], strain_iteration_iles_3[:,2] * 100, 'g', label='Point 3')
plt.axis([0, 100000, -0.8, 0 ])
plt.legend(loc='upper right')
plt.title('Strain - Y')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Strain [%]')
plt.grid(True)

plt.subplot(813)
plt.plot(stress_iteration_iles_0[:,0], stress_iteration_iles_0[:,1], 'y', label='Point 0')
plt.plot(stress_iteration_iles_1[:,0], stress_iteration_iles_1[:,1], 'r--', label='Point 1')
plt.plot(stress_iteration_iles_2[:,0], stress_iteration_iles_2[:,1], 'b--', label='Point 2')
plt.plot(stress_iteration_iles_3[:,0], stress_iteration_iles_3[:,1], 'g', label='Point 3')
plt.axis([0, 100000, -0.03, 0])
plt.legend(loc='lower right')
plt.title('Stress - X')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Stress [Pa]')
plt.grid(True)

plt.subplot(814)
plt.plot(stress_iteration_iles_0[:,0], stress_iteration_iles_0[:,2], 'y', label='Point 0')
plt.plot(stress_iteration_iles_1[:,0], stress_iteration_iles_1[:,2], 'r--', label='Point 1')
plt.plot(stress_iteration_iles_2[:,0], stress_iteration_iles_2[:,2], 'b--', label='Point 2')
plt.plot(stress_iteration_iles_3[:,0], stress_iteration_iles_3[:,2], 'g', label='Point 3')
plt.axis([0, 100000, -50000, 0])
plt.legend(loc='upper right')
plt.title('Stress - Y')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Stress [Pa]')
plt.grid(True)

plt.subplot(815)
plt.plot(acceleration_iteration_iles_0[:,0], acceleration_iteration_iles_0[:,1], 'y', label='Point 0')
plt.plot(acceleration_iteration_iles_1[:,0], acceleration_iteration_iles_1[:,1], 'r--', label='Point 1')
plt.plot(acceleration_iteration_iles_2[:,0], acceleration_iteration_iles_2[:,1], 'b--', label='Point 2')
plt.plot(acceleration_iteration_iles_3[:,0], acceleration_iteration_iles_3[:,1], 'g', label='Point 3')
plt.axis([0, 100000, -0.1, 0.1])
plt.legend(loc='upper right')
plt.title('Acceleration - X')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Acceleration [m / s^2]')
plt.grid(True)

plt.subplot(816)
plt.plot(acceleration_iteration_iles_0[:,0], acceleration_iteration_iles_0[:,2], 'y', label='Point 0')
plt.plot(acceleration_iteration_iles_1[:,0], acceleration_iteration_iles_1[:,2], 'r--', label='Point 1')
plt.plot(acceleration_iteration_iles_2[:,0], acceleration_iteration_iles_2[:,2], 'b--', label='Point 2')
plt.plot(acceleration_iteration_iles_3[:,0], acceleration_iteration_iles_3[:,2], 'g', label='Point 3')
plt.axis([0, 100000, -0.001, 0.001])
plt.legend(loc='lower right')
plt.title('Acceleration - Y')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Acceleration [m / s^2]')
plt.grid(True)

plt.subplot(817)
plt.plot(velocity_iteration_iles_0[:,0], velocity_iteration_iles_0[:,1], 'y', label='Point 0')
plt.plot(velocity_iteration_iles_1[:,0], velocity_iteration_iles_1[:,1], 'r--', label='Point 1')
plt.plot(velocity_iteration_iles_2[:,0], velocity_iteration_iles_2[:,1], 'b--', label='Point 2')
plt.plot(velocity_iteration_iles_3[:,0], velocity_iteration_iles_3[:,1], 'g', label='Point 3')
plt.axis([0, 100000, 0, 0.0005])
plt.legend(loc='lower right')
plt.title('Velocity - X')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Velocity [m / s]')
plt.grid(True)

plt.subplot(818)
plt.plot(velocity_iteration_iles_0[:,0], velocity_iteration_iles_0[:,2], 'y', label='Point 0')
plt.plot(velocity_iteration_iles_1[:,0], velocity_iteration_iles_1[:,2], 'r--', label='Point 1')
plt.plot(velocity_iteration_iles_2[:,0], velocity_iteration_iles_2[:,2], 'b--', label='Point 2')
plt.plot(velocity_iteration_iles_3[:,0], velocity_iteration_iles_3[:,2], 'g', label='Point 3')
plt.axis([0, 100000, -0.002, 0])
plt.legend(loc='lower right')
plt.title('Velocity - Y')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Velocity [m / s]')
plt.grid(True)

plt.show()

# %% [markdown]
# # 6 Mohr Coulomb with Iteration
# ## Velocity on top only

# %%
# Getting more data

stress_iteration_mc_0 = np.genfromtxt("test_d2/stress_0.txt")
stress_iteration_mc_1 = np.genfromtxt("test_d2/stress_1.txt")
stress_iteration_mc_2 = np.genfromtxt("test_d2/stress_2.txt")
stress_iteration_mc_3 = np.genfromtxt("test_d2/stress_3.txt")

strain_iteration_mc_0 = np.genfromtxt("test_d2/strain_0.txt")
strain_iteration_mc_1 = np.genfromtxt("test_d2/strain_1.txt")
strain_iteration_mc_2 = np.genfromtxt("test_d2/strain_2.txt")
strain_iteration_mc_3 = np.genfromtxt("test_d2/strain_3.txt")

acceleration_iteration_mc_0 = np.genfromtxt("test_d2/acceleration_0.txt")
acceleration_iteration_mc_1 = np.genfromtxt("test_d2/acceleration_1.txt")
acceleration_iteration_mc_2 = np.genfromtxt("test_d2/acceleration_2.txt")
acceleration_iteration_mc_3 = np.genfromtxt("test_d2/acceleration_3.txt")

velocity_iteration_mc_0 = np.genfromtxt("test_d2/velocity_0.txt")
velocity_iteration_mc_1 = np.genfromtxt("test_d2/velocity_1.txt")
velocity_iteration_mc_2 = np.genfromtxt("test_d2/velocity_2.txt")
velocity_iteration_mc_3 = np.genfromtxt("test_d2/velocity_3.txt")

# %%
# Plot Comparison

plt.figure(figsize=(16,48))

plt.subplot(811)
plt.plot(strain_iteration_mc_0[:,0], strain_iteration_mc_0[:,1] * 100, 'y', label='Point 0')
plt.plot(strain_iteration_mc_1[:,0], strain_iteration_mc_1[:,1] * 100, 'r--', label='Point 1')
plt.plot(strain_iteration_mc_2[:,0], strain_iteration_mc_2[:,1] * 100, 'b--', label='Point 2')
plt.plot(strain_iteration_mc_3[:,0], strain_iteration_mc_3[:,1] * 100, 'g', label='Point 3')
plt.axis([0, 100000, 0, 0.5])
plt.legend(loc='upper right')
plt.title('Strain - X')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Strain [%]')
plt.grid(True)

plt.subplot(812)
plt.plot(strain_iteration_mc_0[:,0], strain_iteration_mc_0[:,2] * 100, 'y', label='Point 0')
plt.plot(strain_iteration_mc_1[:,0], strain_iteration_mc_1[:,2] * 100, 'r--', label='Point 1')
plt.plot(strain_iteration_mc_2[:,0], strain_iteration_mc_2[:,2] * 100, 'b--', label='Point 2')
plt.plot(strain_iteration_mc_3[:,0], strain_iteration_mc_3[:,2] * 100, 'g', label='Point 3')
plt.axis([0, 100000, -0.5, 0 ])
plt.legend(loc='upper right')
plt.title('Strain - Y')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Strain [%]')
plt.grid(True)

plt.subplot(813)
plt.plot(stress_iteration_mc_0[:,0], stress_iteration_mc_0[:,1], 'y', label='Point 0')
plt.plot(stress_iteration_mc_1[:,0], stress_iteration_mc_1[:,1], 'r--', label='Point 1')
plt.plot(stress_iteration_mc_2[:,0], stress_iteration_mc_2[:,1], 'b--', label='Point 2')
plt.plot(stress_iteration_mc_3[:,0], stress_iteration_mc_3[:,1], 'g', label='Point 3')
plt.axis([0, 100000, -0.1, 0])
plt.legend(loc='lower right')
plt.title('Stress - X')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Stress [Pa]')
plt.grid(True)

plt.subplot(814)
plt.plot(stress_iteration_mc_0[:,0], stress_iteration_mc_0[:,2], 'y', label='Point 0')
plt.plot(stress_iteration_mc_1[:,0], stress_iteration_mc_1[:,2], 'r--', label='Point 1')
plt.plot(stress_iteration_mc_2[:,0], stress_iteration_mc_2[:,2], 'b--', label='Point 2')
plt.plot(stress_iteration_mc_3[:,0], stress_iteration_mc_3[:,2], 'g', label='Point 3')
plt.axis([0, 100000, -5000, 0])
plt.legend(loc='upper right')
plt.title('Stress - Y')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Stress [Pa]')
plt.grid(True)

plt.subplot(815)
plt.plot(acceleration_iteration_mc_0[:,0], acceleration_iteration_mc_0[:,1], 'y', label='Point 0')
plt.plot(acceleration_iteration_mc_1[:,0], acceleration_iteration_mc_1[:,1], 'r--', label='Point 1')
plt.plot(acceleration_iteration_mc_2[:,0], acceleration_iteration_mc_2[:,1], 'b--', label='Point 2')
plt.plot(acceleration_iteration_mc_3[:,0], acceleration_iteration_mc_3[:,1], 'g', label='Point 3')
plt.axis([0, 100000, -0.2, 0.2])
plt.legend(loc='lower right')
plt.title('Acceleration - X')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Acceleration [m / s^2]')
plt.grid(True)

plt.subplot(816)
plt.plot(acceleration_iteration_mc_0[:,0], acceleration_iteration_mc_0[:,2], 'y', label='Point 0')
plt.plot(acceleration_iteration_mc_1[:,0], acceleration_iteration_mc_1[:,2], 'r--', label='Point 1')
plt.plot(acceleration_iteration_mc_2[:,0], acceleration_iteration_mc_2[:,2], 'b--', label='Point 2')
plt.plot(acceleration_iteration_mc_3[:,0], acceleration_iteration_mc_3[:,2], 'g', label='Point 3')
plt.axis([0, 100000, -0.001, 0.001])
plt.legend(loc='lower right')
plt.title('Acceleration - Y')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Acceleration [m / s^2]')
plt.grid(True)

plt.subplot(817)
plt.plot(velocity_iteration_mc_0[:,0], velocity_iteration_mc_0[:,1], 'y', label='Point 0')
plt.plot(velocity_iteration_mc_1[:,0], velocity_iteration_mc_1[:,1], 'r--', label='Point 1')
plt.plot(velocity_iteration_mc_2[:,0], velocity_iteration_mc_2[:,1], 'b--', label='Point 2')
plt.plot(velocity_iteration_mc_3[:,0], velocity_iteration_mc_3[:,1], 'g', label='Point 3')
plt.axis([0, 100000, 0, 0.003])
plt.legend(loc='upper left')
plt.title('Velocity - X')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Velocity [m / s]')
plt.grid(True)

plt.subplot(818)
plt.plot(velocity_iteration_mc_0[:,0], velocity_iteration_mc_0[:,2], 'y', label='Point 0')
plt.plot(velocity_iteration_mc_1[:,0], velocity_iteration_mc_1[:,2], 'r--', label='Point 1')
plt.plot(velocity_iteration_mc_2[:,0], velocity_iteration_mc_2[:,2], 'b--', label='Point 2')
plt.plot(velocity_iteration_mc_3[:,0], velocity_iteration_mc_3[:,2], 'g', label='Point 3')
plt.axis([0, 100000, -0.002, 0])
plt.legend(loc='lower right')
plt.title('Velocity - Y')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Velocity [m / s]')
plt.grid(True)

plt.show()

# %%
# Plot Comparison for Psi = 0, No Damping
plt.figure(figsize=(16,16))

plt.subplot(221)
plt.plot(plaxis_psi0[:,0] * -100, plaxis_psi0[:,1] * 1000, 'k', label='PLAXIS')
plt.plot(strain_iteration_mc_0[:,2] * -100 , stress_iteration_mc_0[:,2] * -1, 'y', label='Point 0')
plt.plot(strain_iteration_mc_1[:,2] * -100 , stress_iteration_mc_1[:,2] * -1, 'r--', label='Point 1')
plt.plot(strain_iteration_mc_2[:,2] * -100 , stress_iteration_mc_2[:,2] * -1, 'b--', label='Point 2')
plt.plot(strain_iteration_mc_3[:,2] * -100 , stress_iteration_mc_3[:,2] * -1, 'g', label='Point 3')
plt.axis([0, 0.2, 0, 5000])
plt.legend(loc='lower right')
plt.title('No Damping, Vertical Stress, $\Psi = 0$')
plt.xlabel('Axial Strain [%]')
plt.ylabel('Axial Stress (Pa)')
plt.grid(True)

plt.subplot(222)
plt.plot(plaxis_psi0[:,0] * -100, plaxis_psi0[:,2] * -100, 'k', label='PLAXIS')
plt.plot(strain_iteration_mc_0[:,2] * -100 , (strain_iteration_mc_0[:,2] + strain_iteration_mc_0[:,1]) * -100, 'y', label='Point 0')
plt.plot(strain_iteration_mc_1[:,2] * -100 , (strain_iteration_mc_1[:,2] + strain_iteration_mc_1[:,1]) * -100, 'r--', label='Point 1')
plt.plot(strain_iteration_mc_2[:,2] * -100 , (strain_iteration_mc_2[:,2] + strain_iteration_mc_2[:,1]) * -100, 'b--', label='Point 2')
plt.plot(strain_iteration_mc_3[:,2] * -100 , (strain_iteration_mc_3[:,2] + strain_iteration_mc_3[:,1]) * -100, 'g', label='Point 3')
plt.axis([0, 0.2, -0.02, 0.06])
plt.legend(loc='upper left')
plt.title('No Damping, $\Psi = 0$')
plt.xlabel('Axial Strain [%]')
plt.ylabel('Volumetric Strain [%]')
plt.grid(True)    

plt.subplot(223)
plt.plot(strain_iteration_mc_0[:,2] * -100 , stress_iteration_mc_0[:,1] * -1, 'y', label='Point 0')
plt.plot(strain_iteration_mc_1[:,2] * -100 , stress_iteration_mc_1[:,1] * -1, 'r--', label='Point 1')
plt.plot(strain_iteration_mc_2[:,2] * -100 , stress_iteration_mc_2[:,1] * -1, 'b--', label='Point 2')
plt.plot(strain_iteration_mc_3[:,2] * -100 , stress_iteration_mc_3[:,1] * -1, 'g', label='Point 3')
plt.axis([0, 0.2, 0, 300])
plt.legend(loc='upper right')
plt.title('No Damping, Horizontal Stress, $\Psi = 0$')
plt.xlabel('Axial Strain [%]')
plt.ylabel('Horizontal Stress (Pa)')
plt.grid(True)

plt.show()
