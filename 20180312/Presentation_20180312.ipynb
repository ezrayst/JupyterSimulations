# %% [markdown]
# # MPM Verification

# %%
# Import Matplotlib
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import Image

# %% [markdown]
# ## Column Collapse (Single Phase)

# %% [markdown]
# Figures below by Shyamini Kularathna
#
# This test tracks the stress at Point ID: 1 (bottom left), 20 (bottom center) and 420 (middle center)
# Regardless, other data (acceleration, velocity and strain) are available for plotting if needed.

# %%
Image("image/4.1.png")

# %%
Image("image/4.2.png")

# %%
normal_initialstress_stress_1 = np.genfromtxt("normal/initialstress/stress_1.txt")
normal_initialstress_stress_20 = np.genfromtxt("normal/initialstress/stress_20.txt")
normal_initialstress_stress_420 = np.genfromtxt("normal/initialstress/stress_420.txt")
normal_initialstress_stress_83 = np.genfromtxt("normal/initialstress/stress_83.txt")

normal_initialstress_strain_1 = np.genfromtxt("normal/initialstress/strain_1.txt")
normal_initialstress_strain_20 = np.genfromtxt("normal/initialstress/strain_20.txt")
normal_initialstress_strain_420 = np.genfromtxt("normal/initialstress/strain_420.txt")
normal_initialstress_strain_83 = np.genfromtxt("normal/initialstress/strain_83.txt")

normal_initialstress_acceleration_1 = np.genfromtxt("normal/initialstress/acceleration_1.txt")
normal_initialstress_acceleration_20 = np.genfromtxt("normal/initialstress/acceleration_20.txt")
normal_initialstress_acceleration_420 = np.genfromtxt("normal/initialstress/acceleration_420.txt")
normal_initialstress_acceleration_83 = np.genfromtxt("normal/initialstress/acceleration_83.txt")

normal_initialstress_velocity_1 = np.genfromtxt("normal/initialstress/velocity_1.txt")
normal_initialstress_velocity_20 = np.genfromtxt("normal/initialstress/velocity_20.txt")
normal_initialstress_velocity_420 = np.genfromtxt("normal/initialstress/velocity_420.txt")
normal_initialstress_velocity_83 = np.genfromtxt("normal/initialstress/velocity_83.txt")

normal_damping02_stress_1 = np.genfromtxt("normal/damping02/stress_1.txt")
normal_damping02_stress_20 = np.genfromtxt("normal/damping02/stress_20.txt")
normal_damping02_stress_420 = np.genfromtxt("normal/damping02/stress_420.txt")
normal_damping02_stress_83 = np.genfromtxt("normal/damping02/stress_83.txt")

normal_damping02_strain_1 = np.genfromtxt("normal/damping02/strain_1.txt")
normal_damping02_strain_20 = np.genfromtxt("normal/damping02/strain_20.txt")
normal_damping02_strain_420 = np.genfromtxt("normal/damping02/strain_420.txt")
normal_damping02_strain_83 = np.genfromtxt("normal/damping02/strain_83.txt")

normal_damping02_acceleration_1 = np.genfromtxt("normal/damping02/acceleration_1.txt")
normal_damping02_acceleration_20 = np.genfromtxt("normal/damping02/acceleration_20.txt")
normal_damping02_acceleration_420 = np.genfromtxt("normal/damping02/acceleration_420.txt")
normal_damping02_acceleration_83 = np.genfromtxt("normal/damping02/acceleration_83.txt")

normal_damping02_velocity_1 = np.genfromtxt("normal/damping02/velocity_1.txt")
normal_damping02_velocity_20 = np.genfromtxt("normal/damping02/velocity_20.txt")
normal_damping02_velocity_420 = np.genfromtxt("normal/damping02/velocity_420.txt")
normal_damping02_velocity_83 = np.genfromtxt("normal/damping02/velocity_83.txt")

gauss_initialstress_stress_1 = np.genfromtxt("gauss/initialstress/stress_1.txt")
gauss_initialstress_stress_20 = np.genfromtxt("gauss/initialstress/stress_20.txt")
gauss_initialstress_stress_420 = np.genfromtxt("gauss/initialstress/stress_420.txt")
gauss_initialstress_stress_83 = np.genfromtxt("gauss/initialstress/stress_83.txt")

gauss_initialstress_strain_1 = np.genfromtxt("gauss/initialstress/strain_1.txt")
gauss_initialstress_strain_20 = np.genfromtxt("gauss/initialstress/strain_20.txt")
gauss_initialstress_strain_420 = np.genfromtxt("gauss/initialstress/strain_420.txt")
gauss_initialstress_strain_83 = np.genfromtxt("gauss/initialstress/strain_83.txt")

gauss_initialstress_acceleration_1 = np.genfromtxt("gauss/initialstress/acceleration_1.txt")
gauss_initialstress_acceleration_20 = np.genfromtxt("gauss/initialstress/acceleration_20.txt")
gauss_initialstress_acceleration_420 = np.genfromtxt("gauss/initialstress/acceleration_420.txt")
gauss_initialstress_acceleration_83 = np.genfromtxt("gauss/initialstress/acceleration_83.txt")

gauss_initialstress_velocity_1 = np.genfromtxt("gauss/initialstress/velocity_1.txt")
gauss_initialstress_velocity_20 = np.genfromtxt("gauss/initialstress/velocity_20.txt")
gauss_initialstress_velocity_420 = np.genfromtxt("gauss/initialstress/velocity_420.txt")
gauss_initialstress_velocity_83 = np.genfromtxt("gauss/initialstress/velocity_83.txt")

gauss_damping02_stress_1 = np.genfromtxt("gauss/damping02/stress_1.txt")
gauss_damping02_stress_20 = np.genfromtxt("gauss/damping02/stress_20.txt")
gauss_damping02_stress_420 = np.genfromtxt("gauss/damping02/stress_420.txt")
gauss_damping02_stress_83 = np.genfromtxt("gauss/damping02/stress_83.txt")

gauss_damping02_strain_1 = np.genfromtxt("gauss/damping02/strain_1.txt")
gauss_damping02_strain_20 = np.genfromtxt("gauss/damping02/strain_20.txt")
gauss_damping02_strain_420 = np.genfromtxt("gauss/damping02/strain_420.txt")
gauss_damping02_strain_83 = np.genfromtxt("gauss/damping02/strain_83.txt")

gauss_damping02_acceleration_1 = np.genfromtxt("gauss/damping02/acceleration_1.txt")
gauss_damping02_acceleration_20 = np.genfromtxt("gauss/damping02/acceleration_20.txt")
gauss_damping02_acceleration_420 = np.genfromtxt("gauss/damping02/acceleration_420.txt")
gauss_damping02_acceleration_83 = np.genfromtxt("gauss/damping02/acceleration_83.txt")

gauss_damping02_velocity_1 = np.genfromtxt("gauss/damping02/velocity_1.txt")
gauss_damping02_velocity_20 = np.genfromtxt("gauss/damping02/velocity_20.txt")
gauss_damping02_velocity_420 = np.genfromtxt("gauss/damping02/velocity_420.txt")
gauss_damping02_velocity_83 = np.genfromtxt("gauss/damping02/velocity_83.txt")

# %%
# Plot Comparison

plt.figure(figsize=(16,24))

plt.subplot(411)
plt.plot(normal_initialstress_stress_20[:,0], normal_initialstress_stress_20[:,2] , 'b', label='Normal - Initial Stress')
plt.plot(normal_damping02_stress_20[:,0], normal_damping02_stress_20[:,2], 'g', label='Normal - 2% Damping')
plt.plot(gauss_initialstress_stress_20[:,0], gauss_initialstress_stress_20[:,2], 'r', label='Gauss - Initial Stress')
plt.plot(gauss_damping02_stress_20[:,0], gauss_damping02_stress_20[:,2], 'y', label='Gauss - 2% Damping')
plt.axis([0, 50000, -3000, 0])
plt.legend(loc='upper right')
plt.title('Stress - Y @ Point 20 (Bottom Center)')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Stress [Pa]')
plt.grid(True)

plt.subplot(412)
plt.plot(normal_initialstress_stress_1[:,0], normal_initialstress_stress_1[:,2] , 'b', label='Normal - Initial Stress')
plt.plot(normal_damping02_stress_1[:,0], normal_damping02_stress_1[:,2], 'g', label='Normal - 2% Damping')
plt.plot(gauss_initialstress_stress_1[:,0], gauss_initialstress_stress_1[:,2], 'r', label='Gauss - Initial Stress')
plt.plot(gauss_damping02_stress_1[:,0], gauss_damping02_stress_1[:,2], 'y', label='Gauss - 2% Damping')
plt.axis([0, 50000, -8000, 1000])
plt.legend(loc='upper right')
plt.title('Stress - Y @ Point 1 (Bottom Left)')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Stress [Pa]')
plt.grid(True)

plt.subplot(413)
plt.plot(normal_initialstress_stress_420[:,0], normal_initialstress_stress_420[:,2] , 'b', label='Normal - Initial Stress')
plt.plot(normal_damping02_stress_420[:,0], normal_damping02_stress_420[:,2], 'g', label='Normal - 2% Damping')
plt.plot(gauss_initialstress_stress_420[:,0], gauss_initialstress_stress_420[:,2], 'r', label='Gauss - Initial Stress')
plt.plot(gauss_damping02_stress_420[:,0], gauss_damping02_stress_420[:,2], 'y', label='Gauss - 2% Damping')
plt.axis([0, 50000, -2000, 0])
plt.legend(loc='lower right')
plt.title('Stress - Y @ Point 420 (Middle Center)')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Stress [Pa]')
plt.grid(True)

plt.subplot(414)
plt.plot(normal_initialstress_stress_83[:,0], normal_initialstress_stress_83[:,2] , 'b', label='Normal - Initial Stress')
plt.plot(normal_damping02_stress_83[:,0], normal_damping02_stress_83[:,2], 'g', label='Normal - 2% Damping')
plt.plot(gauss_initialstress_stress_83[:,0], gauss_initialstress_stress_83[:,2], 'r', label='Gauss - Initial Stress')
plt.plot(gauss_damping02_stress_83[:,0], gauss_damping02_stress_83[:,2], 'y', label='Gauss - 2% Damping')
plt.axis([0, 50000, -8000, 0])
plt.legend(loc='lower right')
plt.title('Stress - Y @ Point 83 (Botton Left Oscillating)')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Stress [Pa]')
plt.grid(True)


plt.show()
