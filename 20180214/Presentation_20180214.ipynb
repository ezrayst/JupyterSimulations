# %% [markdown]
# # MPM Verification

# %%
# Import Matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Velocity Controlled
#
# ### It is comparing node discplacement to node displacement, not point in MPM

# %%
# Getting more data

gauss_stress_0 = np.genfromtxt("gauss_m/stress_0.txt")
gauss_stress_1 = np.genfromtxt("gauss_m/stress_1.txt")
gauss_stress_2 = np.genfromtxt("gauss_m/stress_2.txt")
gauss_stress_3 = np.genfromtxt("gauss_m/stress_3.txt")

gauss_strain_0 = np.genfromtxt("gauss_m/strain_0.txt")
gauss_strain_1 = np.genfromtxt("gauss_m/strain_1.txt")
gauss_strain_2 = np.genfromtxt("gauss_m/strain_2.txt")
gauss_strain_3 = np.genfromtxt("gauss_m/strain_3.txt")

gauss_acceleration_0 = np.genfromtxt("gauss_m/acceleration_0.txt")
gauss_acceleration_1 = np.genfromtxt("gauss_m/acceleration_1.txt")
gauss_acceleration_2 = np.genfromtxt("gauss_m/acceleration_2.txt")
gauss_acceleration_3 = np.genfromtxt("gauss_m/acceleration_3.txt")

gauss_velocity_0 = np.genfromtxt("gauss_m/velocity_0.txt")
gauss_velocity_1 = np.genfromtxt("gauss_m/velocity_1.txt")
gauss_velocity_2 = np.genfromtxt("gauss_m/velocity_2.txt")
gauss_velocity_3 = np.genfromtxt("gauss_m/velocity_3.txt")

normal_stress_0 = np.genfromtxt("normal_m/stress_0.txt")
normal_stress_1 = np.genfromtxt("normal_m/stress_1.txt")
normal_stress_2 = np.genfromtxt("normal_m/stress_2.txt")
normal_stress_3 = np.genfromtxt("normal_m/stress_3.txt")

normal_strain_0 = np.genfromtxt("normal_m/strain_0.txt")
normal_strain_1 = np.genfromtxt("normal_m/strain_1.txt")
normal_strain_2 = np.genfromtxt("normal_m/strain_2.txt")
normal_strain_3 = np.genfromtxt("normal_m/strain_3.txt")

normal_acceleration_0 = np.genfromtxt("normal_m/acceleration_0.txt")
normal_acceleration_1 = np.genfromtxt("normal_m/acceleration_1.txt")
normal_acceleration_2 = np.genfromtxt("normal_m/acceleration_2.txt")
normal_acceleration_3 = np.genfromtxt("normal_m/acceleration_3.txt")

normal_velocity_0 = np.genfromtxt("normal_m/velocity_0.txt")
normal_velocity_1 = np.genfromtxt("normal_m/velocity_1.txt")
normal_velocity_2 = np.genfromtxt("normal_m/velocity_2.txt")
normal_velocity_3 = np.genfromtxt("normal_m/velocity_3.txt")

# %%
# Plot Comparison

plt.figure(figsize=(16,48))

plt.subplot(811)
plt.plot(normal_strain_0[:,0], normal_strain_0[:,1] * 100, 'r', label='Normal')
plt.plot(gauss_strain_0[:,0], gauss_strain_0[:,1] * 100, 'b--', label='Gauss')
#plt.axis([0, 100000, 0, 0.5])
plt.legend(loc='upper left')
plt.title('Strain - X')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Strain [%]')
plt.grid(True)

plt.subplot(812)
plt.plot(normal_strain_0[:,0], normal_strain_0[:,2] * 100, 'r', label='Normal')
plt.plot(gauss_strain_0[:,0], gauss_strain_0[:,2] * 100, 'b--', label='Gauss')
#plt.axis([0, 100000, -1, 0 ])
plt.legend(loc='lower left')
plt.title('Strain - Y')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Strain [%]')
plt.grid(True)

plt.subplot(813)
plt.plot(normal_stress_0[:,0], normal_stress_0[:,1], 'r', label='Normal')
plt.plot(gauss_stress_0[:,0], gauss_stress_0[:,1], 'b--', label='Gauss')
#plt.axis([0, 100000, 0, 0.5])
plt.legend(loc='lower left')
plt.title('Stress - X')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Stress [Pa]')
plt.grid(True)

plt.subplot(814)
plt.plot(normal_stress_0[:,0], normal_stress_0[:,2], 'r', label='Normal')
plt.plot(gauss_stress_0[:,0], gauss_stress_0[:,2], 'b--', label='Gauss')
#plt.axis([0, 100000, -1, 0 ])
plt.legend(loc='lower left')
plt.title('Stress - Y')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Stress [Pa]')
plt.grid(True)

plt.subplot(815)
plt.plot(normal_acceleration_0[:,0], normal_acceleration_0[:,1], 'r', label='Normal')
plt.plot(gauss_acceleration_0[:,0], gauss_acceleration_0[:,1], 'b--', label='Gauss')
#plt.axis([0, 100000, 0, 0.5])
plt.legend(loc='lower left')
plt.title('Acceleration - X')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Acceleration [m / s^2]')
plt.grid(True)

plt.subplot(816)
plt.plot(normal_acceleration_0[:,0], normal_acceleration_0[:,2], 'r', label='Normal')
plt.plot(gauss_acceleration_0[:,0], gauss_acceleration_0[:,2], 'b--', label='Gauss')
#plt.axis([0, 100000, -1, 0 ])
plt.legend(loc='upper left')
plt.title('Acceleration - Y')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Acceleration [m / s^2]')
plt.grid(True)

plt.subplot(817)
plt.plot(normal_velocity_0[:,0], normal_velocity_0[:,1], 'r', label='Normal')
plt.plot(gauss_velocity_0[:,0], gauss_velocity_0[:,1], 'b--', label='Gauss')
#plt.axis([0, 100000, 0, 0.5])
plt.legend(loc='lower right')
plt.title('Velocity - X')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Velocity [m / s]')
plt.grid(True)

plt.subplot(818)
plt.plot(normal_velocity_0[:,0], normal_velocity_0[:,2], 'r', label='Normal')
plt.plot(gauss_velocity_0[:,0], gauss_velocity_0[:,2], 'b--', label='Gauss')
#plt.axis([0, 100000, -1, 0 ])
plt.legend(loc='lower right')
plt.title('Velocity - Y')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Velocity [m / s]')
plt.grid(True)

plt.show()

# %% [markdown]
# Initial Position of the points:
#
# - 0.25  0.25	0
# - 0.75	0.25	0
# - 0.25	0.75	0
# - 0.75	0.75	0
#
#
# Position at 1s with Original Scheme:
#
# - 0.2495 0.2505 0.
# - 0.7505 0.2505 0.
# - 0.2495 0.7495 0.
# - 0.7505 0.7495 0.
#
# Position at 1s with Gauss Integration:
#
# - 0.25 0.2505 0.
# - 0.75 0.2505 0.
# - 0.25 0.7495 0.
# - 0.75 0.7495 0.
