# %% [markdown]
# # MPM Verification

# %%
# Import Matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
# Import Data
plaxis_psi0 = np.genfromtxt("PLAXIS_psi0.csv", delimiter=",")
plaxis_psi_neg5 = np.genfromtxt("PLAXIS_psi-5.csv", delimiter=",")
plaxis_psi_pos5 = np.genfromtxt("PLAXIS_psi+5.csv", delimiter=",")

# %%
# Plot PLAXIS Results
plt.figure(figsize=(16,8))

plt.subplot(121)
plt.plot(plaxis_psi0[:,0] * -100, plaxis_psi0[:,1] * 1000, 'b', label='$\Psi = 0$')
plt.plot(plaxis_psi_neg5[:,0] * -100, plaxis_psi_neg5[:,1] * 1000, 'r', label='$\Psi = -5$')
plt.plot(plaxis_psi_pos5[:,0] * -100, plaxis_psi_pos5[:,1] * 1000, 'g', label='$\Psi = +5$')
plt.axis([0, 0.2, 0, 4000])
plt.legend(loc='lower right')
plt.title('PLAXIS')
plt.xlabel('Axial Strain [%]')
plt.ylabel('Axial Stress (Pa)')
plt.grid(True)

plt.subplot(122)
plt.plot(plaxis_psi0[:,0] * -100, plaxis_psi0[:,2] * -100, 'b', label='$\Psi = 0$')
plt.plot(plaxis_psi_neg5[:,0] * -100, plaxis_psi_neg5[:,2] * -100, 'r', label='$\Psi = -5$')
plt.plot(plaxis_psi_pos5[:,0] * -100, plaxis_psi_pos5[:,2] * -100, 'g', label='$\Psi = +5$')
plt.axis([0, 0.2, -0.02, 0.06])
plt.legend(loc='upper left')
plt.title('PLAXIS')
plt.xlabel('Axial Strain [%]')
plt.ylabel('Volumetric Strain [%]')
plt.grid(True)    
    
plt.show()

# %% [markdown]
# ## Plotting all 4 points in Element
#
# - Point 0: botom left
# - Point 1: bottom right
# - Point 2: upper left
# - Point 3: upper right

# %% [markdown]
# # Mohr Coulomb with Iteration
# ## 1 Velocity on top only, $\psi = 0$

# %%
# Getting more data

stress_iteration_mc_0 = np.genfromtxt("test_d2/stress_0.txt")
stress_iteration_mc_1 = np.genfromtxt("test_d2/stress_1.txt")
stress_iteration_mc_2 = np.genfromtxt("test_d2/stress_2.txt")
stress_iteration_mc_3 = np.genfromtxt("test_d2/stress_3.txt")

strain_iteration_mc_0 = np.genfromtxt("test_d2/strain_0.txt")
strain_iteration_mc_1 = np.genfromtxt("test_d2/strain_1.txt")
strain_iteration_mc_2 = np.genfromtxt("test_d2/strain_2.txt")
strain_iteration_mc_3 = np.genfromtxt("test_d2/strain_3.txt")

acceleration_iteration_mc_0 = np.genfromtxt("test_d2/acceleration_0.txt")
acceleration_iteration_mc_1 = np.genfromtxt("test_d2/acceleration_1.txt")
acceleration_iteration_mc_2 = np.genfromtxt("test_d2/acceleration_2.txt")
acceleration_iteration_mc_3 = np.genfromtxt("test_d2/acceleration_3.txt")

velocity_iteration_mc_0 = np.genfromtxt("test_d2/velocity_0.txt")
velocity_iteration_mc_1 = np.genfromtxt("test_d2/velocity_1.txt")
velocity_iteration_mc_2 = np.genfromtxt("test_d2/velocity_2.txt")
velocity_iteration_mc_3 = np.genfromtxt("test_d2/velocity_3.txt")

# %%
# Plot Comparison

plt.figure(figsize=(16,48))

plt.subplot(811)
plt.plot(strain_iteration_mc_0[:,0], strain_iteration_mc_0[:,1] * 100, 'y', label='Point 0')
plt.plot(strain_iteration_mc_1[:,0], strain_iteration_mc_1[:,1] * 100, 'r--', label='Point 1')
plt.plot(strain_iteration_mc_2[:,0], strain_iteration_mc_2[:,1] * 100, 'b--', label='Point 2')
plt.plot(strain_iteration_mc_3[:,0], strain_iteration_mc_3[:,1] * 100, 'g', label='Point 3')
plt.axis([0, 100000, 0, 0.5])
plt.legend(loc='upper right')
plt.title('Strain - X')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Strain [%]')
plt.grid(True)

plt.subplot(812)
plt.plot(strain_iteration_mc_0[:,0], strain_iteration_mc_0[:,2] * 100, 'y', label='Point 0')
plt.plot(strain_iteration_mc_1[:,0], strain_iteration_mc_1[:,2] * 100, 'r--', label='Point 1')
plt.plot(strain_iteration_mc_2[:,0], strain_iteration_mc_2[:,2] * 100, 'b--', label='Point 2')
plt.plot(strain_iteration_mc_3[:,0], strain_iteration_mc_3[:,2] * 100, 'g', label='Point 3')
plt.axis([0, 100000, -0.5, 0 ])
plt.legend(loc='upper right')
plt.title('Strain - Y')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Strain [%]')
plt.grid(True)

plt.subplot(813)
plt.plot(stress_iteration_mc_0[:,0], stress_iteration_mc_0[:,1], 'y', label='Point 0')
plt.plot(stress_iteration_mc_1[:,0], stress_iteration_mc_1[:,1], 'r--', label='Point 1')
plt.plot(stress_iteration_mc_2[:,0], stress_iteration_mc_2[:,1], 'b--', label='Point 2')
plt.plot(stress_iteration_mc_3[:,0], stress_iteration_mc_3[:,1], 'g', label='Point 3')
plt.axis([0, 100000, -0.1, 0])
plt.legend(loc='lower right')
plt.title('Stress - X')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Stress [Pa]')
plt.grid(True)

plt.subplot(814)
plt.plot(stress_iteration_mc_0[:,0], stress_iteration_mc_0[:,2], 'y', label='Point 0')
plt.plot(stress_iteration_mc_1[:,0], stress_iteration_mc_1[:,2], 'r--', label='Point 1')
plt.plot(stress_iteration_mc_2[:,0], stress_iteration_mc_2[:,2], 'b--', label='Point 2')
plt.plot(stress_iteration_mc_3[:,0], stress_iteration_mc_3[:,2], 'g', label='Point 3')
plt.axis([0, 100000, -5000, 0])
plt.legend(loc='upper right')
plt.title('Stress - Y')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Stress [Pa]')
plt.grid(True)

plt.subplot(815)
plt.plot(acceleration_iteration_mc_0[:,0], acceleration_iteration_mc_0[:,1], 'y', label='Point 0')
plt.plot(acceleration_iteration_mc_1[:,0], acceleration_iteration_mc_1[:,1], 'r--', label='Point 1')
plt.plot(acceleration_iteration_mc_2[:,0], acceleration_iteration_mc_2[:,1], 'b--', label='Point 2')
plt.plot(acceleration_iteration_mc_3[:,0], acceleration_iteration_mc_3[:,1], 'g', label='Point 3')
plt.axis([0, 100000, -0.2, 0.2])
plt.legend(loc='lower right')
plt.title('Acceleration - X')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Acceleration [m / s^2]')
plt.grid(True)

plt.subplot(816)
plt.plot(acceleration_iteration_mc_0[:,0], acceleration_iteration_mc_0[:,2], 'y', label='Point 0')
plt.plot(acceleration_iteration_mc_1[:,0], acceleration_iteration_mc_1[:,2], 'r--', label='Point 1')
plt.plot(acceleration_iteration_mc_2[:,0], acceleration_iteration_mc_2[:,2], 'b--', label='Point 2')
plt.plot(acceleration_iteration_mc_3[:,0], acceleration_iteration_mc_3[:,2], 'g', label='Point 3')
plt.axis([0, 100000, -0.001, 0.001])
plt.legend(loc='lower right')
plt.title('Acceleration - Y')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Acceleration [m / s^2]')
plt.grid(True)

plt.subplot(817)
plt.plot(velocity_iteration_mc_0[:,0], velocity_iteration_mc_0[:,1], 'y', label='Point 0')
plt.plot(velocity_iteration_mc_1[:,0], velocity_iteration_mc_1[:,1], 'r--', label='Point 1')
plt.plot(velocity_iteration_mc_2[:,0], velocity_iteration_mc_2[:,1], 'b--', label='Point 2')
plt.plot(velocity_iteration_mc_3[:,0], velocity_iteration_mc_3[:,1], 'g', label='Point 3')
plt.axis([0, 100000, 0, 0.003])
plt.legend(loc='upper left')
plt.title('Velocity - X')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Velocity [m / s]')
plt.grid(True)

plt.subplot(818)
plt.plot(velocity_iteration_mc_0[:,0], velocity_iteration_mc_0[:,2], 'y', label='Point 0')
plt.plot(velocity_iteration_mc_1[:,0], velocity_iteration_mc_1[:,2], 'r--', label='Point 1')
plt.plot(velocity_iteration_mc_2[:,0], velocity_iteration_mc_2[:,2], 'b--', label='Point 2')
plt.plot(velocity_iteration_mc_3[:,0], velocity_iteration_mc_3[:,2], 'g', label='Point 3')
plt.axis([0, 100000, -0.002, 0])
plt.legend(loc='lower right')
plt.title('Velocity - Y')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Velocity [m / s]')
plt.grid(True)

plt.show()

# %% [markdown]
# ## 2 Velocity on top only, $\psi = -5$

# %%
# Getting more data

stress_iteration_mc_neg5_0 = np.genfromtxt("test_d3/stress_0.txt")
stress_iteration_mc_neg5_1 = np.genfromtxt("test_d3/stress_1.txt")
stress_iteration_mc_neg5_2 = np.genfromtxt("test_d3/stress_2.txt")
stress_iteration_mc_neg5_3 = np.genfromtxt("test_d3/stress_3.txt")

strain_iteration_mc_neg5_0 = np.genfromtxt("test_d3/strain_0.txt")
strain_iteration_mc_neg5_1 = np.genfromtxt("test_d3/strain_1.txt")
strain_iteration_mc_neg5_2 = np.genfromtxt("test_d3/strain_2.txt")
strain_iteration_mc_neg5_3 = np.genfromtxt("test_d3/strain_3.txt")

acceleration_iteration_mc_neg5_0 = np.genfromtxt("test_d3/acceleration_0.txt")
acceleration_iteration_mc_neg5_1 = np.genfromtxt("test_d3/acceleration_1.txt")
acceleration_iteration_mc_neg5_2 = np.genfromtxt("test_d3/acceleration_2.txt")
acceleration_iteration_mc_neg5_3 = np.genfromtxt("test_d3/acceleration_3.txt")

velocity_iteration_mc_neg5_0 = np.genfromtxt("test_d3/velocity_0.txt")
velocity_iteration_mc_neg5_1 = np.genfromtxt("test_d3/velocity_1.txt")
velocity_iteration_mc_neg5_2 = np.genfromtxt("test_d3/velocity_2.txt")
velocity_iteration_mc_neg5_3 = np.genfromtxt("test_d3/velocity_3.txt")

# %%
# Plot Comparison

plt.figure(figsize=(16,48))

plt.subplot(811)
plt.plot(strain_iteration_mc_neg5_0[:,0], strain_iteration_mc_neg5_0[:,1] * 100, 'y', label='Point 0')
plt.plot(strain_iteration_mc_neg5_1[:,0], strain_iteration_mc_neg5_1[:,1] * 100, 'r--', label='Point 1')
plt.plot(strain_iteration_mc_neg5_2[:,0], strain_iteration_mc_neg5_2[:,1] * 100, 'b--', label='Point 2')
plt.plot(strain_iteration_mc_neg5_3[:,0], strain_iteration_mc_neg5_3[:,1] * 100, 'g', label='Point 3')
plt.axis([0, 100000, 0, 0.5])
plt.legend(loc='upper right')
plt.title('Strain - X')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Strain [%]')
plt.grid(True)

plt.subplot(812)
plt.plot(strain_iteration_mc_neg5_0[:,0], strain_iteration_mc_neg5_0[:,2] * 100, 'y', label='Point 0')
plt.plot(strain_iteration_mc_neg5_1[:,0], strain_iteration_mc_neg5_1[:,2] * 100, 'r--', label='Point 1')
plt.plot(strain_iteration_mc_neg5_2[:,0], strain_iteration_mc_neg5_2[:,2] * 100, 'b--', label='Point 2')
plt.plot(strain_iteration_mc_neg5_3[:,0], strain_iteration_mc_neg5_3[:,2] * 100, 'g', label='Point 3')
plt.axis([0, 100000, -0.5, 0 ])
plt.legend(loc='upper right')
plt.title('Strain - Y')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Strain [%]')
plt.grid(True)

plt.subplot(813)
plt.plot(stress_iteration_mc_neg5_0[:,0], stress_iteration_mc_neg5_0[:,1], 'y', label='Point 0')
plt.plot(stress_iteration_mc_neg5_1[:,0], stress_iteration_mc_neg5_1[:,1], 'r--', label='Point 1')
plt.plot(stress_iteration_mc_neg5_2[:,0], stress_iteration_mc_neg5_2[:,1], 'b--', label='Point 2')
plt.plot(stress_iteration_mc_neg5_3[:,0], stress_iteration_mc_neg5_3[:,1], 'g', label='Point 3')
plt.axis([0, 100000, -0.1, 0])
plt.legend(loc='lower right')
plt.title('Stress - X')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Stress [Pa]')
plt.grid(True)

plt.subplot(814)
plt.plot(stress_iteration_mc_neg5_0[:,0], stress_iteration_mc_neg5_0[:,2], 'y', label='Point 0')
plt.plot(stress_iteration_mc_neg5_1[:,0], stress_iteration_mc_neg5_1[:,2], 'r--', label='Point 1')
plt.plot(stress_iteration_mc_neg5_2[:,0], stress_iteration_mc_neg5_2[:,2], 'b--', label='Point 2')
plt.plot(stress_iteration_mc_neg5_3[:,0], stress_iteration_mc_neg5_3[:,2], 'g', label='Point 3')
plt.axis([0, 100000, -5000, 0])
plt.legend(loc='upper right')
plt.title('Stress - Y')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Stress [Pa]')
plt.grid(True)

plt.subplot(815)
plt.plot(acceleration_iteration_mc_neg5_0[:,0], acceleration_iteration_mc_neg5_0[:,1], 'y', label='Point 0')
plt.plot(acceleration_iteration_mc_neg5_1[:,0], acceleration_iteration_mc_neg5_1[:,1], 'r--', label='Point 1')
plt.plot(acceleration_iteration_mc_neg5_2[:,0], acceleration_iteration_mc_neg5_2[:,1], 'b--', label='Point 2')
plt.plot(acceleration_iteration_mc_neg5_3[:,0], acceleration_iteration_mc_neg5_3[:,1], 'g', label='Point 3')
plt.axis([0, 100000, -0.2, 0.2])
plt.legend(loc='lower right')
plt.title('Acceleration - X')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Acceleration [m / s^2]')
plt.grid(True)

plt.subplot(816)
plt.plot(acceleration_iteration_mc_neg5_0[:,0], acceleration_iteration_mc_neg5_0[:,2], 'y', label='Point 0')
plt.plot(acceleration_iteration_mc_neg5_1[:,0], acceleration_iteration_mc_neg5_1[:,2], 'r--', label='Point 1')
plt.plot(acceleration_iteration_mc_neg5_2[:,0], acceleration_iteration_mc_neg5_2[:,2], 'b--', label='Point 2')
plt.plot(acceleration_iteration_mc_neg5_3[:,0], acceleration_iteration_mc_neg5_3[:,2], 'g', label='Point 3')
plt.axis([0, 100000, -0.001, 0.001])
plt.legend(loc='lower right')
plt.title('Acceleration - Y')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Acceleration [m / s^2]')
plt.grid(True)

plt.subplot(817)
plt.plot(velocity_iteration_mc_neg5_0[:,0], velocity_iteration_mc_neg5_0[:,1], 'y', label='Point 0')
plt.plot(velocity_iteration_mc_neg5_1[:,0], velocity_iteration_mc_neg5_1[:,1], 'r--', label='Point 1')
plt.plot(velocity_iteration_mc_neg5_2[:,0], velocity_iteration_mc_neg5_2[:,1], 'b--', label='Point 2')
plt.plot(velocity_iteration_mc_neg5_3[:,0], velocity_iteration_mc_neg5_3[:,1], 'g', label='Point 3')
plt.axis([0, 100000, 0, 0.003])
plt.legend(loc='upper left')
plt.title('Velocity - X')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Velocity [m / s]')
plt.grid(True)

plt.subplot(818)
plt.plot(velocity_iteration_mc_neg5_0[:,0], velocity_iteration_mc_neg5_0[:,2], 'y', label='Point 0')
plt.plot(velocity_iteration_mc_neg5_1[:,0], velocity_iteration_mc_neg5_1[:,2], 'r--', label='Point 1')
plt.plot(velocity_iteration_mc_neg5_2[:,0], velocity_iteration_mc_neg5_2[:,2], 'b--', label='Point 2')
plt.plot(velocity_iteration_mc_neg5_3[:,0], velocity_iteration_mc_neg5_3[:,2], 'g', label='Point 3')
plt.axis([0, 100000, -0.002, 0])
plt.legend(loc='lower right')
plt.title('Velocity - Y')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Velocity [m / s]')
plt.grid(True)

plt.show()

# %% [markdown]
# ## 3 Velocity on top only, $\psi = 5$

# %%
# Getting more data

stress_iteration_mc_pos5_0 = np.genfromtxt("test_d4/stress_0.txt")
stress_iteration_mc_pos5_1 = np.genfromtxt("test_d4/stress_1.txt")
stress_iteration_mc_pos5_2 = np.genfromtxt("test_d4/stress_2.txt")
stress_iteration_mc_pos5_3 = np.genfromtxt("test_d4/stress_3.txt")

strain_iteration_mc_pos5_0 = np.genfromtxt("test_d4/strain_0.txt")
strain_iteration_mc_pos5_1 = np.genfromtxt("test_d4/strain_1.txt")
strain_iteration_mc_pos5_2 = np.genfromtxt("test_d4/strain_2.txt")
strain_iteration_mc_pos5_3 = np.genfromtxt("test_d4/strain_3.txt")

acceleration_iteration_mc_pos5_0 = np.genfromtxt("test_d4/acceleration_0.txt")
acceleration_iteration_mc_pos5_1 = np.genfromtxt("test_d4/acceleration_1.txt")
acceleration_iteration_mc_pos5_2 = np.genfromtxt("test_d4/acceleration_2.txt")
acceleration_iteration_mc_pos5_3 = np.genfromtxt("test_d4/acceleration_3.txt")

velocity_iteration_mc_pos5_0 = np.genfromtxt("test_d4/velocity_0.txt")
velocity_iteration_mc_pos5_1 = np.genfromtxt("test_d4/velocity_1.txt")
velocity_iteration_mc_pos5_2 = np.genfromtxt("test_d4/velocity_2.txt")
velocity_iteration_mc_pos5_3 = np.genfromtxt("test_d4/velocity_3.txt")

# %%
# Plot Comparison

plt.figure(figsize=(16,48))

plt.subplot(811)
plt.plot(strain_iteration_mc_pos5_0[:,0], strain_iteration_mc_pos5_0[:,1] * 100, 'y', label='Point 0')
plt.plot(strain_iteration_mc_pos5_1[:,0], strain_iteration_mc_pos5_1[:,1] * 100, 'r--', label='Point 1')
plt.plot(strain_iteration_mc_pos5_2[:,0], strain_iteration_mc_pos5_2[:,1] * 100, 'b--', label='Point 2')
plt.plot(strain_iteration_mc_pos5_3[:,0], strain_iteration_mc_pos5_3[:,1] * 100, 'g', label='Point 3')
plt.axis([0, 100000, 0, 0.5])
plt.legend(loc='upper right')
plt.title('Strain - X')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Strain [%]')
plt.grid(True)

plt.subplot(812)
plt.plot(strain_iteration_mc_pos5_0[:,0], strain_iteration_mc_pos5_0[:,2] * 100, 'y', label='Point 0')
plt.plot(strain_iteration_mc_pos5_1[:,0], strain_iteration_mc_pos5_1[:,2] * 100, 'r--', label='Point 1')
plt.plot(strain_iteration_mc_pos5_2[:,0], strain_iteration_mc_pos5_2[:,2] * 100, 'b--', label='Point 2')
plt.plot(strain_iteration_mc_pos5_3[:,0], strain_iteration_mc_pos5_3[:,2] * 100, 'g', label='Point 3')
plt.axis([0, 100000, -0.5, 0 ])
plt.legend(loc='upper right')
plt.title('Strain - Y')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Strain [%]')
plt.grid(True)

plt.subplot(813)
plt.plot(stress_iteration_mc_pos5_0[:,0], stress_iteration_mc_pos5_0[:,1], 'y', label='Point 0')
plt.plot(stress_iteration_mc_pos5_1[:,0], stress_iteration_mc_pos5_1[:,1], 'r--', label='Point 1')
plt.plot(stress_iteration_mc_pos5_2[:,0], stress_iteration_mc_pos5_2[:,1], 'b--', label='Point 2')
plt.plot(stress_iteration_mc_pos5_3[:,0], stress_iteration_mc_pos5_3[:,1], 'g', label='Point 3')
plt.axis([0, 100000, -0.1, 0])
plt.legend(loc='lower right')
plt.title('Stress - X')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Stress [Pa]')
plt.grid(True)

plt.subplot(814)
plt.plot(stress_iteration_mc_pos5_0[:,0], stress_iteration_mc_pos5_0[:,2], 'y', label='Point 0')
plt.plot(stress_iteration_mc_pos5_1[:,0], stress_iteration_mc_pos5_1[:,2], 'r--', label='Point 1')
plt.plot(stress_iteration_mc_pos5_2[:,0], stress_iteration_mc_pos5_2[:,2], 'b--', label='Point 2')
plt.plot(stress_iteration_mc_pos5_3[:,0], stress_iteration_mc_pos5_3[:,2], 'g', label='Point 3')
plt.axis([0, 100000, -5000, 0])
plt.legend(loc='upper right')
plt.title('Stress - Y')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Stress [Pa]')
plt.grid(True)

plt.subplot(815)
plt.plot(acceleration_iteration_mc_pos5_0[:,0], acceleration_iteration_mc_pos5_0[:,1], 'y', label='Point 0')
plt.plot(acceleration_iteration_mc_pos5_1[:,0], acceleration_iteration_mc_pos5_1[:,1], 'r--', label='Point 1')
plt.plot(acceleration_iteration_mc_pos5_2[:,0], acceleration_iteration_mc_pos5_2[:,1], 'b--', label='Point 2')
plt.plot(acceleration_iteration_mc_pos5_3[:,0], acceleration_iteration_mc_pos5_3[:,1], 'g', label='Point 3')
plt.axis([0, 100000, -0.2, 0.2])
plt.legend(loc='lower right')
plt.title('Acceleration - X')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Acceleration [m / s^2]')
plt.grid(True)

plt.subplot(816)
plt.plot(acceleration_iteration_mc_pos5_0[:,0], acceleration_iteration_mc_pos5_0[:,2], 'y', label='Point 0')
plt.plot(acceleration_iteration_mc_pos5_1[:,0], acceleration_iteration_mc_pos5_1[:,2], 'r--', label='Point 1')
plt.plot(acceleration_iteration_mc_pos5_2[:,0], acceleration_iteration_mc_pos5_2[:,2], 'b--', label='Point 2')
plt.plot(acceleration_iteration_mc_pos5_3[:,0], acceleration_iteration_mc_pos5_3[:,2], 'g', label='Point 3')
plt.axis([0, 100000, -0.001, 0.001])
plt.legend(loc='lower right')
plt.title('Acceleration - Y')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Acceleration [m / s^2]')
plt.grid(True)

plt.subplot(817)
plt.plot(velocity_iteration_mc_pos5_0[:,0], velocity_iteration_mc_pos5_0[:,1], 'y', label='Point 0')
plt.plot(velocity_iteration_mc_pos5_1[:,0], velocity_iteration_mc_pos5_1[:,1], 'r--', label='Point 1')
plt.plot(velocity_iteration_mc_pos5_2[:,0], velocity_iteration_mc_pos5_2[:,1], 'b--', label='Point 2')
plt.plot(velocity_iteration_mc_pos5_3[:,0], velocity_iteration_mc_pos5_3[:,1], 'g', label='Point 3')
plt.axis([0, 100000, 0, 0.003])
plt.legend(loc='upper left')
plt.title('Velocity - X')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Velocity [m / s]')
plt.grid(True)

plt.subplot(818)
plt.plot(velocity_iteration_mc_pos5_0[:,0], velocity_iteration_mc_pos5_0[:,2], 'y', label='Point 0')
plt.plot(velocity_iteration_mc_pos5_1[:,0], velocity_iteration_mc_pos5_1[:,2], 'r--', label='Point 1')
plt.plot(velocity_iteration_mc_pos5_2[:,0], velocity_iteration_mc_pos5_2[:,2], 'b--', label='Point 2')
plt.plot(velocity_iteration_mc_pos5_3[:,0], velocity_iteration_mc_pos5_3[:,2], 'g', label='Point 3')
plt.axis([0, 100000, -0.002, 0])
plt.legend(loc='lower right')
plt.title('Velocity - Y')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Velocity [m / s]')
plt.grid(True)

plt.show()

# %%
# Plot Comparison

plt.figure(figsize=(16,24))

plt.subplot(321)
plt.plot(plaxis_psi0[:,0] * -100, plaxis_psi0[:,1] * 1000, 'k', label='PLAXIS')
plt.plot(strain_iteration_mc_0[:,2] * -100 , stress_iteration_mc_0[:,2] * -1, 'y', label='Point 0')
plt.plot(strain_iteration_mc_1[:,2] * -100 , stress_iteration_mc_1[:,2] * -1, 'r--', label='Point 1')
plt.plot(strain_iteration_mc_2[:,2] * -100 , stress_iteration_mc_2[:,2] * -1, 'b--', label='Point 2')
plt.plot(strain_iteration_mc_3[:,2] * -100 , stress_iteration_mc_3[:,2] * -1, 'g', label='Point 3')
plt.axis([0, 0.2, 0, 5000])
plt.legend(loc='lower right')
plt.title('No Damping, Vertical Stress, $\Psi = 0$')
plt.xlabel('Axial Strain [%]')
plt.ylabel('Axial Stress (Pa)')
plt.grid(True)

plt.subplot(322)
plt.plot(plaxis_psi0[:,0] * -100, plaxis_psi0[:,2] * -100, 'k', label='PLAXIS')
plt.plot(strain_iteration_mc_0[:,2] * -100 , (strain_iteration_mc_0[:,2] + strain_iteration_mc_0[:,1]) * -100, 'y', label='Point 0')
plt.plot(strain_iteration_mc_1[:,2] * -100 , (strain_iteration_mc_1[:,2] + strain_iteration_mc_1[:,1]) * -100, 'r--', label='Point 1')
plt.plot(strain_iteration_mc_2[:,2] * -100 , (strain_iteration_mc_2[:,2] + strain_iteration_mc_2[:,1]) * -100, 'b--', label='Point 2')
plt.plot(strain_iteration_mc_3[:,2] * -100 , (strain_iteration_mc_3[:,2] + strain_iteration_mc_3[:,1]) * -100, 'g', label='Point 3')
plt.axis([0, 0.2, -0.02, 0.06])
plt.legend(loc='upper left')
plt.title('No Damping, $\Psi = 0$')
plt.xlabel('Axial Strain [%]')
plt.ylabel('Volumetric Strain [%]')
plt.grid(True)    

plt.subplot(323)
plt.plot(plaxis_psi_neg5[:,0] * -100, plaxis_psi_neg5[:,1] * 1000, 'k', label='PLAXIS')
plt.plot(strain_iteration_mc_neg5_0[:,2] * -100 , stress_iteration_mc_neg5_0[:,2] * -1, 'y', label='Point 0')
plt.plot(strain_iteration_mc_neg5_1[:,2] * -100 , stress_iteration_mc_neg5_1[:,2] * -1, 'r--', label='Point 1')
plt.plot(strain_iteration_mc_neg5_2[:,2] * -100 , stress_iteration_mc_neg5_2[:,2] * -1, 'b--', label='Point 2')
plt.plot(strain_iteration_mc_neg5_3[:,2] * -100 , stress_iteration_mc_neg5_3[:,2] * -1, 'g', label='Point 3')
plt.axis([0, 0.2, 0, 5000])
plt.legend(loc='lower right')
plt.title('No Damping, Vertical Stress, $\Psi = -5$')
plt.xlabel('Axial Strain [%]')
plt.ylabel('Axial Stress (Pa)')
plt.grid(True)

plt.subplot(324)
plt.plot(plaxis_psi_neg5[:,0] * -100, plaxis_psi_neg5[:,2] * -100, 'k', label='PLAXIS')
plt.plot(strain_iteration_mc_neg5_0[:,2] * -100 , (strain_iteration_mc_neg5_0[:,2] + strain_iteration_mc_neg5_0[:,1]) * -100, 'y', label='Point 0')
plt.plot(strain_iteration_mc_neg5_1[:,2] * -100 , (strain_iteration_mc_neg5_1[:,2] + strain_iteration_mc_neg5_1[:,1]) * -100, 'r--', label='Point 1')
plt.plot(strain_iteration_mc_neg5_2[:,2] * -100 , (strain_iteration_mc_neg5_2[:,2] + strain_iteration_mc_neg5_2[:,1]) * -100, 'b--', label='Point 2')
plt.plot(strain_iteration_mc_neg5_3[:,2] * -100 , (strain_iteration_mc_neg5_3[:,2] + strain_iteration_mc_neg5_3[:,1]) * -100, 'g', label='Point 3')
plt.axis([0, 0.2, -0.02, 0.06])
plt.legend(loc='upper left')
plt.title('No Damping, $\Psi = -5$')
plt.xlabel('Axial Strain [%]')
plt.ylabel('Volumetric Strain [%]')
plt.grid(True)    

plt.subplot(325)
plt.plot(plaxis_psi_pos5[:,0] * -100, plaxis_psi_pos5[:,1] * 1000, 'k', label='PLAXIS')
plt.plot(strain_iteration_mc_pos5_0[:,2] * -100 , stress_iteration_mc_pos5_0[:,2] * -1, 'y', label='Point 0')
plt.plot(strain_iteration_mc_pos5_1[:,2] * -100 , stress_iteration_mc_pos5_1[:,2] * -1, 'r--', label='Point 1')
plt.plot(strain_iteration_mc_pos5_2[:,2] * -100 , stress_iteration_mc_pos5_2[:,2] * -1, 'b--', label='Point 2')
plt.plot(strain_iteration_mc_pos5_3[:,2] * -100 , stress_iteration_mc_pos5_3[:,2] * -1, 'g', label='Point 3')
plt.axis([0, 0.2, 0, 5000])
plt.legend(loc='lower right')
plt.title('No Damping, Vertical Stress, $\Psi = 5$')
plt.xlabel('Axial Strain [%]')
plt.ylabel('Axial Stress (Pa)')
plt.grid(True)

plt.subplot(326)
plt.plot(plaxis_psi_pos5[:,0] * -100, plaxis_psi_pos5[:,2] * -100, 'k', label='PLAXIS')
plt.plot(strain_iteration_mc_pos5_0[:,2] * -100 , (strain_iteration_mc_pos5_0[:,2] + strain_iteration_mc_pos5_0[:,1]) * -100, 'y', label='Point 0')
plt.plot(strain_iteration_mc_pos5_1[:,2] * -100 , (strain_iteration_mc_pos5_1[:,2] + strain_iteration_mc_pos5_1[:,1]) * -100, 'r--', label='Point 1')
plt.plot(strain_iteration_mc_pos5_2[:,2] * -100 , (strain_iteration_mc_pos5_2[:,2] + strain_iteration_mc_pos5_2[:,1]) * -100, 'b--', label='Point 2')
plt.plot(strain_iteration_mc_pos5_3[:,2] * -100 , (strain_iteration_mc_pos5_3[:,2] + strain_iteration_mc_pos5_3[:,1]) * -100, 'g', label='Point 3')
plt.axis([0, 0.2, -0.02, 0.06])
plt.legend(loc='upper left')
plt.title('No Damping, $\Psi = 5$')
plt.xlabel('Axial Strain [%]')
plt.ylabel('Volumetric Strain [%]')
plt.grid(True)

plt.show()

# %% [markdown]
# ## 4 Velocity on top and bottom

# %%
# Getting more data

stress_iteration_mc_n_0 = np.genfromtxt("test_e2/stress_0.txt")
stress_iteration_mc_n_1 = np.genfromtxt("test_e2/stress_1.txt")
stress_iteration_mc_n_2 = np.genfromtxt("test_e2/stress_2.txt")
stress_iteration_mc_n_3 = np.genfromtxt("test_e2/stress_3.txt")

strain_iteration_mc_n_0 = np.genfromtxt("test_e2/strain_0.txt")
strain_iteration_mc_n_1 = np.genfromtxt("test_e2/strain_1.txt")
strain_iteration_mc_n_2 = np.genfromtxt("test_e2/strain_2.txt")
strain_iteration_mc_n_3 = np.genfromtxt("test_e2/strain_3.txt")

acceleration_iteration_mc_n_0 = np.genfromtxt("test_e2/acceleration_0.txt")
acceleration_iteration_mc_n_1 = np.genfromtxt("test_e2/acceleration_1.txt")
acceleration_iteration_mc_n_2 = np.genfromtxt("test_e2/acceleration_2.txt")
acceleration_iteration_mc_n_3 = np.genfromtxt("test_e2/acceleration_3.txt")

velocity_iteration_mc_n_0 = np.genfromtxt("test_e2/velocity_0.txt")
velocity_iteration_mc_n_1 = np.genfromtxt("test_e2/velocity_1.txt")
velocity_iteration_mc_n_2 = np.genfromtxt("test_e2/velocity_2.txt")
velocity_iteration_mc_n_3 = np.genfromtxt("test_e2/velocity_3.txt")

stress_iteration_mc_n_neg5_0 = np.genfromtxt("test_e3/stress_0.txt")
stress_iteration_mc_n_neg5_1 = np.genfromtxt("test_e3/stress_1.txt")
stress_iteration_mc_n_neg5_2 = np.genfromtxt("test_e3/stress_2.txt")
stress_iteration_mc_n_neg5_3 = np.genfromtxt("test_e3/stress_3.txt")

strain_iteration_mc_n_neg5_0 = np.genfromtxt("test_e3/strain_0.txt")
strain_iteration_mc_n_neg5_1 = np.genfromtxt("test_e3/strain_1.txt")
strain_iteration_mc_n_neg5_2 = np.genfromtxt("test_e3/strain_2.txt")
strain_iteration_mc_n_neg5_3 = np.genfromtxt("test_e3/strain_3.txt")

acceleration_iteration_mc_n_neg5_0 = np.genfromtxt("test_e3/acceleration_0.txt")
acceleration_iteration_mc_n_neg5_1 = np.genfromtxt("test_e3/acceleration_1.txt")
acceleration_iteration_mc_n_neg5_2 = np.genfromtxt("test_e3/acceleration_2.txt")
acceleration_iteration_mc_n_neg5_3 = np.genfromtxt("test_e3/acceleration_3.txt")

velocity_iteration_mc_n_neg5_0 = np.genfromtxt("test_e3/velocity_0.txt")
velocity_iteration_mc_n_neg5_1 = np.genfromtxt("test_e3/velocity_1.txt")
velocity_iteration_mc_n_neg5_2 = np.genfromtxt("test_e3/velocity_2.txt")
velocity_iteration_mc_n_neg5_3 = np.genfromtxt("test_e3/velocity_3.txt")

stress_iteration_mc_n_pos5_0 = np.genfromtxt("test_e4/stress_0.txt")
stress_iteration_mc_n_pos5_1 = np.genfromtxt("test_e4/stress_1.txt")
stress_iteration_mc_n_pos5_2 = np.genfromtxt("test_e4/stress_2.txt")
stress_iteration_mc_n_pos5_3 = np.genfromtxt("test_e4/stress_3.txt")

strain_iteration_mc_n_pos5_0 = np.genfromtxt("test_e4/strain_0.txt")
strain_iteration_mc_n_pos5_1 = np.genfromtxt("test_e4/strain_1.txt")
strain_iteration_mc_n_pos5_2 = np.genfromtxt("test_e4/strain_2.txt")
strain_iteration_mc_n_pos5_3 = np.genfromtxt("test_e4/strain_3.txt")

acceleration_iteration_mc_n_pos5_0 = np.genfromtxt("test_e4/acceleration_0.txt")
acceleration_iteration_mc_n_pos5_1 = np.genfromtxt("test_e4/acceleration_1.txt")
acceleration_iteration_mc_n_pos5_2 = np.genfromtxt("test_e4/acceleration_2.txt")
acceleration_iteration_mc_n_pos5_3 = np.genfromtxt("test_e4/acceleration_3.txt")

velocity_iteration_mc_n_pos5_0 = np.genfromtxt("test_e4/velocity_0.txt")
velocity_iteration_mc_n_pos5_1 = np.genfromtxt("test_e4/velocity_1.txt")
velocity_iteration_mc_n_pos5_2 = np.genfromtxt("test_e4/velocity_2.txt")
velocity_iteration_mc_n_pos5_3 = np.genfromtxt("test_e4/velocity_3.txt")

# %%
# Plot Comparison

plt.figure(figsize=(16,24))

plt.subplot(321)
plt.plot(plaxis_psi0[:,0] * -100, plaxis_psi0[:,1] * 1000, 'k', label='PLAXIS')
plt.plot(strain_iteration_mc_n_0[:,2] * -100 , stress_iteration_mc_n_0[:,2] * -1, 'y', label='Point 0')
plt.plot(strain_iteration_mc_n_1[:,2] * -100 , stress_iteration_mc_n_1[:,2] * -1, 'r--', label='Point 1')
plt.plot(strain_iteration_mc_n_2[:,2] * -100 , stress_iteration_mc_n_2[:,2] * -1, 'b--', label='Point 2')
plt.plot(strain_iteration_mc_n_3[:,2] * -100 , stress_iteration_mc_n_3[:,2] * -1, 'g', label='Point 3')
plt.axis([0, 0.2, 0, 5000])
plt.legend(loc='lower right')
plt.title('No Damping, Vertical Stress, $\Psi = 0$')
plt.xlabel('Axial Strain [%]')
plt.ylabel('Axial Stress (Pa)')
plt.grid(True)

plt.subplot(322)
plt.plot(plaxis_psi0[:,0] * -100, plaxis_psi0[:,2] * -100, 'k', label='PLAXIS')
plt.plot(strain_iteration_mc_n_0[:,2] * -100 , (strain_iteration_mc_n_0[:,2] + strain_iteration_mc_n_0[:,1]) * -100, 'y', label='Point 0')
plt.plot(strain_iteration_mc_n_1[:,2] * -100 , (strain_iteration_mc_n_1[:,2] + strain_iteration_mc_n_1[:,1]) * -100, 'r--', label='Point 1')
plt.plot(strain_iteration_mc_n_2[:,2] * -100 , (strain_iteration_mc_n_2[:,2] + strain_iteration_mc_n_2[:,1]) * -100, 'b--', label='Point 2')
plt.plot(strain_iteration_mc_n_3[:,2] * -100 , (strain_iteration_mc_n_3[:,2] + strain_iteration_mc_n_3[:,1]) * -100, 'g', label='Point 3')
plt.axis([0, 0.2, -0.02, 0.06])
plt.legend(loc='upper left')
plt.title('No Damping, $\Psi = 0$')
plt.xlabel('Axial Strain [%]')
plt.ylabel('Volumetric Strain [%]')
plt.grid(True)    

plt.subplot(323)
plt.plot(plaxis_psi_neg5[:,0] * -100, plaxis_psi_neg5[:,1] * 1000, 'k', label='PLAXIS')
plt.plot(strain_iteration_mc_n_neg5_0[:,2] * -100 , stress_iteration_mc_n_neg5_0[:,2] * -1, 'y', label='Point 0')
plt.plot(strain_iteration_mc_n_neg5_1[:,2] * -100 , stress_iteration_mc_n_neg5_1[:,2] * -1, 'r--', label='Point 1')
plt.plot(strain_iteration_mc_n_neg5_2[:,2] * -100 , stress_iteration_mc_n_neg5_2[:,2] * -1, 'b--', label='Point 2')
plt.plot(strain_iteration_mc_n_neg5_3[:,2] * -100 , stress_iteration_mc_n_neg5_3[:,2] * -1, 'g', label='Point 3')
plt.axis([0, 0.2, 0, 5000])
plt.legend(loc='lower right')
plt.title('No Damping, Vertical Stress, $\Psi = -5$')
plt.xlabel('Axial Strain [%]')
plt.ylabel('Axial Stress (Pa)')
plt.grid(True)

plt.subplot(324)
plt.plot(plaxis_psi_neg5[:,0] * -100, plaxis_psi_neg5[:,2] * -100, 'k', label='PLAXIS')
plt.plot(strain_iteration_mc_n_neg5_0[:,2] * -100 , (strain_iteration_mc_n_neg5_0[:,2] + strain_iteration_mc_n_neg5_0[:,1]) * -100, 'y', label='Point 0')
plt.plot(strain_iteration_mc_n_neg5_1[:,2] * -100 , (strain_iteration_mc_n_neg5_1[:,2] + strain_iteration_mc_n_neg5_1[:,1]) * -100, 'r--', label='Point 1')
plt.plot(strain_iteration_mc_n_neg5_2[:,2] * -100 , (strain_iteration_mc_n_neg5_2[:,2] + strain_iteration_mc_n_neg5_2[:,1]) * -100, 'b--', label='Point 2')
plt.plot(strain_iteration_mc_n_neg5_3[:,2] * -100 , (strain_iteration_mc_n_neg5_3[:,2] + strain_iteration_mc_n_neg5_3[:,1]) * -100, 'g', label='Point 3')
plt.axis([0, 0.2, -0.02, 0.06])
plt.legend(loc='upper left')
plt.title('No Damping, $\Psi = -5$')
plt.xlabel('Axial Strain [%]')
plt.ylabel('Volumetric Strain [%]')
plt.grid(True)    

plt.subplot(325)
plt.plot(plaxis_psi_pos5[:,0] * -100, plaxis_psi_pos5[:,1] * 1000, 'k', label='PLAXIS')
plt.plot(strain_iteration_mc_n_pos5_0[:,2] * -100 , stress_iteration_mc_n_pos5_0[:,2] * -1, 'y', label='Point 0')
plt.plot(strain_iteration_mc_n_pos5_1[:,2] * -100 , stress_iteration_mc_n_pos5_1[:,2] * -1, 'r--', label='Point 1')
plt.plot(strain_iteration_mc_n_pos5_2[:,2] * -100 , stress_iteration_mc_n_pos5_2[:,2] * -1, 'b--', label='Point 2')
plt.plot(strain_iteration_mc_n_pos5_3[:,2] * -100 , stress_iteration_mc_n_pos5_3[:,2] * -1, 'g', label='Point 3')
plt.axis([0, 0.2, 0, 5000])
plt.legend(loc='lower right')
plt.title('No Damping, Vertical Stress, $\Psi = 5$')
plt.xlabel('Axial Strain [%]')
plt.ylabel('Axial Stress (Pa)')
plt.grid(True)

plt.subplot(326)
plt.plot(plaxis_psi_pos5[:,0] * -100, plaxis_psi_pos5[:,2] * -100, 'k', label='PLAXIS')
plt.plot(strain_iteration_mc_n_pos5_0[:,2] * -100 , (strain_iteration_mc_n_pos5_0[:,2] + strain_iteration_mc_n_pos5_0[:,1]) * -100, 'y', label='Point 0')
plt.plot(strain_iteration_mc_n_pos5_1[:,2] * -100 , (strain_iteration_mc_n_pos5_1[:,2] + strain_iteration_mc_n_pos5_1[:,1]) * -100, 'r--', label='Point 1')
plt.plot(strain_iteration_mc_n_pos5_2[:,2] * -100 , (strain_iteration_mc_n_pos5_2[:,2] + strain_iteration_mc_n_pos5_2[:,1]) * -100, 'b--', label='Point 2')
plt.plot(strain_iteration_mc_n_pos5_3[:,2] * -100 , (strain_iteration_mc_n_pos5_3[:,2] + strain_iteration_mc_n_pos5_3[:,1]) * -100, 'g', label='Point 3')
plt.axis([0, 0.2, -0.02, 0.06])
plt.legend(loc='upper left')
plt.title('No Damping, $\Psi = 5$')
plt.xlabel('Axial Strain [%]')
plt.ylabel('Volumetric Strain [%]')
plt.grid(True)

plt.show()
