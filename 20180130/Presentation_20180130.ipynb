# %% [markdown]
# # MPM Verification

# %%
# Import Matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Velocity Controlled
#
# ### It is comparing node discplacement to node displacement, not point in MPM

# %%
# Getting more data

stress_0 = np.genfromtxt("results/stress_0.txt")
stress_1 = np.genfromtxt("results/stress_1.txt")
stress_2 = np.genfromtxt("results/stress_2.txt")
stress_3 = np.genfromtxt("results/stress_3.txt")
stress_4 = np.genfromtxt("results/stress_4.txt")
stress_5 = np.genfromtxt("results/stress_5.txt")
stress_6 = np.genfromtxt("results/stress_6.txt")
stress_7 = np.genfromtxt("results/stress_7.txt")
stress_8 = np.genfromtxt("results/stress_8.txt")
stress_9 = np.genfromtxt("results/stress_9.txt")
stress_10 = np.genfromtxt("results/stress_10.txt")
stress_11 = np.genfromtxt("results/stress_11.txt")

strain_0 = np.genfromtxt("results/strain_0.txt")
strain_1 = np.genfromtxt("results/strain_1.txt")
strain_2 = np.genfromtxt("results/strain_2.txt")
strain_3 = np.genfromtxt("results/strain_3.txt")
strain_4 = np.genfromtxt("results/strain_4.txt")
strain_5 = np.genfromtxt("results/strain_5.txt")
strain_6 = np.genfromtxt("results/strain_6.txt")
strain_7 = np.genfromtxt("results/strain_7.txt")
strain_8 = np.genfromtxt("results/strain_8.txt")
strain_9 = np.genfromtxt("results/strain_9.txt")
strain_10 = np.genfromtxt("results/strain_10.txt")
strain_11 = np.genfromtxt("results/strain_11.txt")

acceleration_0 = np.genfromtxt("results/acceleration_0.txt")
acceleration_1 = np.genfromtxt("results/acceleration_1.txt")
acceleration_2 = np.genfromtxt("results/acceleration_2.txt")
acceleration_3 = np.genfromtxt("results/acceleration_3.txt")
acceleration_4 = np.genfromtxt("results/acceleration_4.txt")
acceleration_5 = np.genfromtxt("results/acceleration_5.txt")
acceleration_6 = np.genfromtxt("results/acceleration_6.txt")
acceleration_7 = np.genfromtxt("results/acceleration_7.txt")
acceleration_8 = np.genfromtxt("results/acceleration_8.txt")
acceleration_9 = np.genfromtxt("results/acceleration_9.txt")
acceleration_10 = np.genfromtxt("results/acceleration_10.txt")
acceleration_11 = np.genfromtxt("results/acceleration_11.txt")

velocity_0 = np.genfromtxt("results/velocity_0.txt")
velocity_1 = np.genfromtxt("results/velocity_1.txt")
velocity_2 = np.genfromtxt("results/velocity_2.txt")
velocity_3 = np.genfromtxt("results/velocity_3.txt")
velocity_4 = np.genfromtxt("results/velocity_4.txt")
velocity_5 = np.genfromtxt("results/velocity_5.txt")
velocity_6 = np.genfromtxt("results/velocity_6.txt")
velocity_7 = np.genfromtxt("results/velocity_7.txt")
velocity_8 = np.genfromtxt("results/velocity_8.txt")
velocity_9 = np.genfromtxt("results/velocity_9.txt")
velocity_10 = np.genfromtxt("results/velocity_10.txt")
velocity_11 = np.genfromtxt("results/velocity_11.txt")

# %%
# Plot Comparison

plt.figure(figsize=(16,48))

plt.subplot(811)
plt.plot(strain_0[:,0], strain_0[:,1] * 100, 'b--', label='Point 0')
plt.plot(strain_1[:,0], strain_1[:,1] * 100, 'r', label='Point 1')
plt.plot(strain_4[:,0], strain_4[:,1] * 100, 'y--', label='Point 4')
plt.plot(strain_5[:,0], strain_5[:,1] * 100, 'g', label='Point 5')
plt.plot(strain_8[:,0], strain_8[:,1] * 100, 'm--', label='Point 8')
plt.plot(strain_9[:,0], strain_9[:,1] * 100, 'c', label='Point 9')
#plt.axis([0, 100000, 0, 0.5])
plt.legend(loc='upper left')
plt.title('Strain - X')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Strain [%]')
plt.grid(True)

plt.subplot(812)
plt.plot(strain_0[:,0], strain_0[:,2] * 100, 'b--', label='Point 0')
plt.plot(strain_1[:,0], strain_1[:,2] * 100, 'r', label='Point 1')
plt.plot(strain_4[:,0], strain_4[:,2] * 100, 'y--', label='Point 4')
plt.plot(strain_5[:,0], strain_5[:,2] * 100, 'g', label='Point 5')
plt.plot(strain_8[:,0], strain_8[:,2] * 100, 'm--', label='Point 8')
plt.plot(strain_9[:,0], strain_9[:,2] * 100, 'c', label='Point 9')
#plt.axis([0, 100000, -1, 0 ])
plt.legend(loc='lower left')
plt.title('Strain - Y')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Strain [%]')
plt.grid(True)

plt.subplot(813)
plt.plot(stress_0[:,0], stress_0[:,1], 'b--', label='Point 0')
plt.plot(stress_1[:,0], stress_1[:,1], 'r', label='Point 1')
plt.plot(stress_4[:,0], stress_4[:,1], 'y--', label='Point 4')
plt.plot(stress_5[:,0], stress_5[:,1], 'g', label='Point 5')
plt.plot(stress_8[:,0], stress_8[:,1], 'm--', label='Point 8')
plt.plot(stress_9[:,0], stress_9[:,1], 'c', label='Point 9')
#plt.axis([0, 100000, 0, 0.5])
plt.legend(loc='upper left')
plt.title('Stress - X')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Stress [Pa]')
plt.grid(True)

plt.subplot(814)
plt.plot(stress_0[:,0], stress_0[:,2], 'b--', label='Point 0')
plt.plot(stress_1[:,0], stress_1[:,2], 'r', label='Point 1')
plt.plot(stress_4[:,0], stress_4[:,2], 'y--', label='Point 4')
plt.plot(stress_5[:,0], stress_5[:,2], 'g', label='Point 5')
plt.plot(stress_8[:,0], stress_8[:,2], 'm--', label='Point 8')
plt.plot(stress_9[:,0], stress_9[:,2], 'c', label='Point 9')
#plt.axis([0, 100000, -1, 0 ])
plt.legend(loc='upper left')
plt.title('Stress - Y')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Stress [Pa]')
plt.grid(True)

plt.subplot(815)
plt.plot(acceleration_0[:,0], acceleration_0[:,1], 'b--', label='Point 0')
plt.plot(acceleration_1[:,0], acceleration_1[:,1], 'r', label='Point 1')
plt.plot(acceleration_4[:,0], acceleration_4[:,1], 'y--', label='Point 4')
plt.plot(acceleration_5[:,0], acceleration_5[:,1], 'g', label='Point 5')
plt.plot(acceleration_8[:,0], acceleration_8[:,1], 'm--', label='Point 8')
plt.plot(acceleration_9[:,0], acceleration_9[:,1], 'c', label='Point 9')
#plt.axis([0, 100000, 0, 0.5])
plt.legend(loc='lower left')
plt.title('Acceleration - X')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Acceleration [m / s^2]')
plt.grid(True)

plt.subplot(816)
plt.plot(acceleration_0[:,0], acceleration_0[:,2], 'b--', label='Point 0')
plt.plot(acceleration_1[:,0], acceleration_1[:,2], 'r', label='Point 1')
plt.plot(acceleration_4[:,0], acceleration_4[:,2], 'y--', label='Point 4')
plt.plot(acceleration_5[:,0], acceleration_5[:,2], 'g', label='Point 5')
plt.plot(acceleration_8[:,0], acceleration_8[:,2], 'm--', label='Point 8')
plt.plot(acceleration_9[:,0], acceleration_9[:,2], 'c', label='Point 9')
#plt.axis([0, 100000, -1, 0 ])
plt.legend(loc='upper left')
plt.title('Acceleration - Y')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Acceleration [m / s^2]')
plt.grid(True)

plt.subplot(817)
plt.plot(velocity_0[:,0], velocity_0[:,1], 'b--', label='Point 0')
plt.plot(velocity_1[:,0], velocity_1[:,1], 'r', label='Point 1')
plt.plot(velocity_4[:,0], velocity_4[:,1], 'y--', label='Point 4')
plt.plot(velocity_5[:,0], velocity_5[:,1], 'g', label='Point 5')
plt.plot(velocity_8[:,0], velocity_8[:,1], 'm--', label='Point 8')
plt.plot(velocity_9[:,0], velocity_9[:,1], 'c', label='Point 9')
#plt.axis([0, 100000, 0, 0.5])
plt.legend(loc='lower right')
plt.title('Velocity - X')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Velocity [m / s]')
plt.grid(True)

plt.subplot(818)
plt.plot(velocity_0[:,0], velocity_0[:,2], 'b--', label='Point 0')
plt.plot(velocity_1[:,0], velocity_1[:,2], 'r', label='Point 1')
plt.plot(velocity_4[:,0], velocity_4[:,2], 'y--', label='Point 4')
plt.plot(velocity_5[:,0], velocity_5[:,2], 'g', label='Point 5')
plt.plot(velocity_8[:,0], velocity_8[:,2], 'm--', label='Point 8')
plt.plot(velocity_9[:,0], velocity_9[:,2], 'c', label='Point 9')
#plt.axis([0, 100000, -1, 0 ])
plt.legend(loc='upper left')
plt.title('Velocity - Y')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Velocity [m / s]')
plt.grid(True)

plt.show()
