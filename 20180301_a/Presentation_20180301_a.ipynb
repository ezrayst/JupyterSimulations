# %% [markdown]
# # MPM Verification

# %%
# Import Matplotlib
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import Image

# %% [markdown]
# ## Column Collapse (Single Phase)

# %% [markdown]
# Figures below by Shyamini Kularathna
#
# This test tracks the stress at Point ID: 1 (bottom left), 20 (bottom center) and 420 (middle center)
# Regardless, other data (acceleration, velocity and strain) are available for plotting if needed.

# %%
Image("image/4.1.png")

# %%
Image("image/4.2.png")

# %%
# Getting more data

noinitialstress_stress_1 = np.genfromtxt("noinitialstress/stress_1.txt")
noinitialstress_stress_20 = np.genfromtxt("noinitialstress/stress_20.txt")
noinitialstress_stress_420 = np.genfromtxt("noinitialstress/stress_420.txt")

noinitialstress_strain_1 = np.genfromtxt("noinitialstress/strain_1.txt")
noinitialstress_strain_20 = np.genfromtxt("noinitialstress/strain_20.txt")
noinitialstress_strain_420 = np.genfromtxt("noinitialstress/strain_420.txt")

noinitialstress_acceleration_1 = np.genfromtxt("noinitialstress/acceleration_1.txt")
noinitialstress_acceleration_20 = np.genfromtxt("noinitialstress/acceleration_20.txt")
noinitialstress_acceleration_420 = np.genfromtxt("noinitialstress/acceleration_420.txt")

noinitialstress_velocity_1 = np.genfromtxt("noinitialstress/velocity_1.txt")
noinitialstress_velocity_20 = np.genfromtxt("noinitialstress/velocity_20.txt")
noinitialstress_velocity_420 = np.genfromtxt("noinitialstress/velocity_420.txt")

initialstress_stress_1 = np.genfromtxt("initialstress/stress_1.txt")
initialstress_stress_20 = np.genfromtxt("initialstress/stress_20.txt")
initialstress_stress_420 = np.genfromtxt("initialstress/stress_420.txt")

initialstress_strain_1 = np.genfromtxt("initialstress/strain_1.txt")
initialstress_strain_20 = np.genfromtxt("initialstress/strain_20.txt")
initialstress_strain_420 = np.genfromtxt("initialstress/strain_420.txt")

initialstress_acceleration_1 = np.genfromtxt("initialstress/acceleration_1.txt")
initialstress_acceleration_20 = np.genfromtxt("initialstress/acceleration_20.txt")
initialstress_acceleration_420 = np.genfromtxt("initialstress/acceleration_420.txt")

initialstress_velocity_1 = np.genfromtxt("initialstress/velocity_1.txt")
initialstress_velocity_20 = np.genfromtxt("initialstress/velocity_20.txt")
initialstress_velocity_420 = np.genfromtxt("initialstress/velocity_420.txt")

damping02_stress_1 = np.genfromtxt("damping02/stress_1.txt")
damping02_stress_20 = np.genfromtxt("damping02/stress_20.txt")
damping02_stress_420 = np.genfromtxt("damping02/stress_420.txt")

damping02_strain_1 = np.genfromtxt("damping02/strain_1.txt")
damping02_strain_20 = np.genfromtxt("damping02/strain_20.txt")
damping02_strain_420 = np.genfromtxt("damping02/strain_420.txt")

damping02_acceleration_1 = np.genfromtxt("damping02/acceleration_1.txt")
damping02_acceleration_20 = np.genfromtxt("damping02/acceleration_20.txt")
damping02_acceleration_420 = np.genfromtxt("damping02/acceleration_420.txt")

damping02_velocity_1 = np.genfromtxt("damping02/velocity_1.txt")
damping02_velocity_20 = np.genfromtxt("damping02/velocity_20.txt")
damping02_velocity_420 = np.genfromtxt("damping02/velocity_420.txt")

damping05_stress_1 = np.genfromtxt("damping05/stress_1.txt")
damping05_stress_20 = np.genfromtxt("damping05/stress_20.txt")
damping05_stress_420 = np.genfromtxt("damping05/stress_420.txt")

damping05_strain_1 = np.genfromtxt("damping05/strain_1.txt")
damping05_strain_20 = np.genfromtxt("damping05/strain_20.txt")
damping05_strain_420 = np.genfromtxt("damping05/strain_420.txt")

damping05_acceleration_1 = np.genfromtxt("damping05/acceleration_1.txt")
damping05_acceleration_20 = np.genfromtxt("damping05/acceleration_20.txt")
damping05_acceleration_420 = np.genfromtxt("damping05/acceleration_420.txt")

damping05_velocity_1 = np.genfromtxt("damping05/velocity_1.txt")
damping05_velocity_20 = np.genfromtxt("damping05/velocity_20.txt")
damping05_velocity_420 = np.genfromtxt("damping05/velocity_420.txt")

# %%
# Plot Comparison

plt.figure(figsize=(16,18))

plt.subplot(311)
plt.plot(noinitialstress_stress_20[:,0], noinitialstress_stress_20[:,2], 'r', label='No Initial Stress')
plt.plot(initialstress_stress_20[:,0], initialstress_stress_20[:,2] , 'b', label='With Initial Stress')
plt.plot(damping02_stress_20[:,0], damping02_stress_20[:,2], 'g', label='2% Damping')
plt.plot(damping05_stress_20[:,0], damping05_stress_20[:,2], 'y', label='5% Damping')
plt.axis([0, 50000, -3000, 1000])
plt.legend(loc='upper right')
plt.title('Stress - Y @ Point 20 (Bottom Center)')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Stress [Pa]')
plt.grid(True)

plt.subplot(312)
plt.plot(noinitialstress_stress_1[:,0], noinitialstress_stress_1[:,2], 'r', label='No Initial Stress')
plt.plot(initialstress_stress_1[:,0], initialstress_stress_1[:,2] , 'b', label='With Initial Stress')
plt.plot(damping02_stress_1[:,0], damping02_stress_1[:,2], 'g', label='2% Damping')
plt.plot(damping05_stress_1[:,0], damping05_stress_1[:,2], 'y', label='5% Damping')
plt.axis([0, 50000, -2000, 1000])
plt.legend(loc='upper right')
plt.title('Stress - Y @ Point 1 (Bottom Left)')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Stress [Pa]')
plt.grid(True)

plt.subplot(313)
plt.plot(noinitialstress_stress_420[:,0], noinitialstress_stress_420[:,2], 'r', label='No Initial Stress')
plt.plot(initialstress_stress_420[:,0], initialstress_stress_420[:,2] , 'b', label='With Initial Stress')
plt.plot(damping02_stress_420[:,0], damping02_stress_420[:,2], 'g', label='2% Damping')
plt.plot(damping05_stress_420[:,0], damping05_stress_420[:,2], 'y', label='5% Damping')
plt.axis([0, 50000, -2000, 1000])
plt.legend(loc='lower right')
plt.title('Stress - Y @ Point 420 (Middle Center)')
plt.xlabel('Time Step [10^-5 s]')
plt.ylabel('Stress [Pa]')
plt.grid(True)


plt.show()
